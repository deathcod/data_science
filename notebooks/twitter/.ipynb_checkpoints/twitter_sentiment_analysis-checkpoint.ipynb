# %% [markdown]
# # twitter analysis

# %%
import twitter

# %%
CONSUMER_KEY = 'slAIp8kYfqM4yjEm7G8hzJJo8'
CONSUMER_SECRET = 'kBBNIMiEdLYGTiJt7Lt3oZP52G2X8jM8Os1u82VXs2u1Ape1WN'
OAUTH_TOKEN = '788273630945742849-ghgqY1rsJVeYLBCQZ0IuHfUjz3ejTe1'
OAUTH_TOKEN_SECRET = 'kxuZpgWPjyTVYscJKFml2RI2nvjBRVND4qg878gPEePq9'

# %%
auth = twitter.oauth.OAuth(OAUTH_TOKEN , OAUTH_TOKEN_SECRET , CONSUMER_KEY , CONSUMER_SECRET)

# %%
twitter_api = twitter.Twitter(auth =auth)

# %%
print (twitter_api)
# Out:
# <twitter.api.Twitter object at 0x7fbd1c1ff1d0>

# %% [markdown]
# So here we are checking if the credential's are correct or not,if it is, it will return a Twitter object.

# %%
import json

# %% [markdown]
# #### exploring the trends

# %% [markdown]
# now having received our twitter object, we will start to look into topic which is trending worldwide , but we will be focused on specific locations, and will be using [Yahoo! GeoPlanet’s Where On Earth (WOE) ID system](http://t.umblr.com/redirect?z=https%3A%2F%2Fdeveloper.yahoo.com%2Fgeo%2Fgeoplanet%2F&t=OGM4YzBhNjViNjcxOGQ3NzIxZjdmYWU1OGRmYjQ3NWNjM2Q3NGU0YyxiTzlzN09FTQ%3D%3D&b=t%3Aul2CQmLWLSJwsFh_rOb6AA&m=1)

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977
IND_WOE_ID = 23424848

# %%
world_trends = twitter_api.trends.place(_id = WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id = US_WOE_ID)
india_trends = twitter_api.trends.place(_id = IND_WOE_ID)

# %%
print (json.dumps(world_trends,indent = 2))
# Out:
# [
#   {
#     "created_at": "2016-10-19T02:35:29Z",
#     "as_of": "2016-10-19T02:38:45Z",
#     "trends": [
#       {
#         "tweet_volume": 71446,
#         "url": "http://twitter.com/search?q=%23MasterChefBR",
#         "promoted_content": null,
#         "query": "%23MasterChefBR",
#         "name": "#MasterChefBR"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22Luciano+Castro%22",
#         "promoted_content": null,
#         "query": "%22Luciano+Castro%22",
#         "name": "Luciano Castro"
#       },
#       {
#         "tweet_volume": 69603,
#         "url": "http://twitter.com/search?q=%23SDLive",
#         "promoted_content": null,
#         "query": "%23SDLive",
#         "name": "#SDLive"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23ManosalFuego",
#         "promoted_content": null,
#         "query": "%23ManosalFuego",
#         "name": "#ManosalFuego"
#       },
#       {
#         "tweet_volume": 52613,
#         "url": "http://twitter.com/search?q=%23MTVScreamSpecial",
#         "promoted_content": null,
#         "query": "%23MTVScreamSpecial",
#         "name": "#MTVScreamSpecial"
#       },
#       {
#         "tweet_volume": 16607,
#         "url": "http://twitter.com/search?q=%23FreixoNaRedeTV",
#         "promoted_content": null,
#         "query": "%23FreixoNaRedeTV",
#         "name": "#FreixoNaRedeTV"
#       },
#       {
#         "tweet_volume": 12765,
#         "url": "http://twitter.com/search?q=%22Rich+Hill%22",
#         "promoted_content": null,
#         "query": "%22Rich+Hill%22",
#         "name": "Rich Hill"
#       },
#       {
#         "tweet_volume": 13269,
#         "url": "http://twitter.com/search?q=Caniggia",
#         "promoted_content": null,
#         "query": "Caniggia",
#         "name": "Caniggia"
#       },
#       {
#         "tweet_volume": 13393,
#         "url": "http://twitter.com/search?q=%22Bruna+Marquezine%22",
#         "promoted_content": null,
#         "query": "%22Bruna+Marquezine%22",
#         "name": "Bruna Marquezine"
#       },
#       {
#         "tweet_volume": 175693,
#         "url": "http://twitter.com/search?q=%EC%9D%B4%EC%9E%90%ED%98%9C",
#         "promoted_content": null,
#         "query": "%EC%9D%B4%EC%9E%90%ED%98%9C",
#         "name": "\uc774\uc790\ud61c"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22Dia+de+Gr%C3%AAmio%22",
#         "promoted_content": null,
#         "query": "%22Dia+de+Gr%C3%AAmio%22",
#         "name": "Dia de Gr\u00eamio"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22Premoni%C3%A7%C3%A3o+5%22",
#         "promoted_content": null,
#         "query": "%22Premoni%C3%A7%C3%A3o+5%22",
#         "name": "Premoni\u00e7\u00e3o 5"
#       },
#       {
#         "tweet_volume": 45041,
#         "url": "http://twitter.com/search?q=PSAT",
#         "promoted_content": null,
#         "query": "PSAT",
#         "name": "PSAT"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22Paper+Boi%22",
#         "promoted_content": null,
#         "query": "%22Paper+Boi%22",
#         "name": "Paper Boi"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23Supermax",
#         "promoted_content": null,
#         "query": "%23Supermax",
#         "name": "#Supermax"
#       },
#       {
#         "tweet_volume": 32746,
#         "url": "http://twitter.com/search?q=%23ContactoConMaduro70",
#         "promoted_content": null,
#         "query": "%23ContactoConMaduro70",
#         "name": "#ContactoConMaduro70"
#       },
#       {
#         "tweet_volume": 20853,
#         "url": "http://twitter.com/search?q=%23MOPnaFMODia",
#         "promoted_content": null,
#         "query": "%23MOPnaFMODia",
#         "name": "#MOPnaFMODia"
#       },
#       {
#         "tweet_volume": 12867,
#         "url": "http://twitter.com/search?q=%23MartesIntratable",
#         "promoted_content": null,
#         "query": "%23MartesIntratable",
#         "name": "#MartesIntratable"
#       },
#       {
#         "tweet_volume": 39900,
#         "url": "http://twitter.com/search?q=%23MusicaBoaAoVivo",
#         "promoted_content": null,
#         "query": "%23MusicaBoaAoVivo",
#         "name": "#MusicaBoaAoVivo"
#       },
#       {
#         "tweet_volume": 101431,
#         "url": "http://twitter.com/search?q=%23Limite6GH17",
#         "promoted_content": null,
#         "query": "%23Limite6GH17",
#         "name": "#Limite6GH17"
#       },
#       {
#         "tweet_volume": 29941,
#         "url": "http://twitter.com/search?q=%23YoAmoLaFriendZone",
#         "promoted_content": null,
#         "query": "%23YoAmoLaFriendZone",
#         "name": "#YoAmoLaFriendZone"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23NoWayVideoClipe",
#         "promoted_content": null,
#         "query": "%23NoWayVideoClipe",
#         "name": "#NoWayVideoClipe"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23LadyCuernos",
#         "promoted_content": null,
#         "query": "%23LadyCuernos",
#         "name": "#LadyCuernos"
#       },
#       {
#         "tweet_volume": 280541,
#         "url": "http://twitter.com/search?q=%23AWLMusicVideo",
#         "promoted_content": null,
#         "query": "%23AWLMusicVideo",
#         "name": "#AWLMusicVideo"
#       },
#       {
#         "tweet_volume": 279428,
#         "url": "http://twitter.com/search?q=%23DrainTheSwamp",
#         "promoted_content": null,
#         "query": "%23DrainTheSwamp",
#         "name": "#DrainTheSwamp"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23%D8%A7%D8%B3%D8%A7%D9%85%D8%AD_%D9%83%D9%84_%D8%B4%D8%AE%D8%B5_%D8%A7%D9%84%D8%A7_%D8%A7%D9%84%D9%84%D9%8A",
#         "promoted_content": null,
#         "query": "%23%D8%A7%D8%B3%D8%A7%D9%85%D8%AD_%D9%83%D9%84_%D8%B4%D8%AE%D8%B5_%D8%A7%D9%84%D8%A7_%D8%A7%D9%84%D9%84%D9%8A",
#         "name": "#\u0627\u0633\u0627\u0645\u062d_\u0643\u0644_\u0634\u062e\u0635_\u0627\u0644\u0627_\u0627\u0644\u0644\u064a"
#       },
#       {
#         "tweet_volume": 38653,
#         "url": "http://twitter.com/search?q=%23%D8%A8%D9%83%D9%84_%D8%A7%D8%AE%D8%AA%D8%B5%D8%A7%D8%B1",
#         "promoted_content": null,
#         "query": "%23%D8%A8%D9%83%D9%84_%D8%A7%D8%AE%D8%AA%D8%B5%D8%A7%D8%B1",
#         "name": "#\u0628\u0643\u0644_\u0627\u062e\u062a\u0635\u0627\u0631"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23concluVZLA",
#         "promoted_content": null,
#         "query": "%23concluVZLA",
#         "name": "#concluVZLA"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23IStayHappyBy",
#         "promoted_content": null,
#         "query": "%23IStayHappyBy",
#         "name": "#IStayHappyBy"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23QuieroSaberEPN",
#         "promoted_content": null,
#         "query": "%23QuieroSaberEPN",
#         "name": "#QuieroSaberEPN"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23PhiSlamaJama",
#         "promoted_content": null,
#         "query": "%23PhiSlamaJama",
#         "name": "#PhiSlamaJama"
#       },
#       {
#         "tweet_volume": 12894,
#         "url": "http://twitter.com/search?q=%23%D8%A7%D8%AD%D9%84%D9%8A_%D9%83%D9%84%D9%85%D9%87_%D8%B9%D9%84%D9%8A_%D9%82%D9%84%D8%A8%D9%83",
#         "promoted_content": null,
#         "query": "%23%D8%A7%D8%AD%D9%84%D9%8A_%D9%83%D9%84%D9%85%D9%87_%D8%B9%D9%84%D9%8A_%D9%82%D9%84%D8%A8%D9%83",
#         "name": "#\u0627\u062d\u0644\u064a_\u0643\u0644\u0645\u0647_\u0639\u0644\u064a_\u0642\u0644\u0628\u0643"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23AganarConNitantukkySeguidores",
#         "promoted_content": null,
#         "query": "%23AganarConNitantukkySeguidores",
#         "name": "#AganarConNitantukkySeguidores"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23DesafioSuperHumanos",
#         "promoted_content": null,
#         "query": "%23DesafioSuperHumanos",
#         "name": "#DesafioSuperHumanos"
#       },
#       {
#         "tweet_volume": 11186,
#         "url": "http://twitter.com/search?q=%23GrietaSocial",
#         "promoted_content": null,
#         "query": "%23GrietaSocial",
#         "name": "#GrietaSocial"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23VoteAnittaClipeTVZ",
#         "promoted_content": null,
#         "query": "%23VoteAnittaClipeTVZ",
#         "name": "#VoteAnittaClipeTVZ"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23%D8%B4%D9%8A_%D8%AA%D8%AA%D9%85%D9%86%D8%A7%D9%87_%D9%84%D9%86%D9%81%D8%B3%D9%83",
#         "promoted_content": null,
#         "query": "%23%D8%B4%D9%8A_%D8%AA%D8%AA%D9%85%D9%86%D8%A7%D9%87_%D9%84%D9%86%D9%81%D8%B3%D9%83",
#         "name": "#\u0634\u064a_\u062a\u062a\u0645\u0646\u0627\u0647_\u0644\u0646\u0641\u0633\u0643"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23ShawmilaAppreciation",
#         "promoted_content": null,
#         "query": "%23ShawmilaAppreciation",
#         "name": "#ShawmilaAppreciation"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23TalkingSmack",
#         "promoted_content": null,
#         "query": "%23TalkingSmack",
#         "name": "#TalkingSmack"
#       },
#       {
#         "tweet_volume": 15759,
#         "url": "http://twitter.com/search?q=%23MeMolestaLaGenteQue",
#         "promoted_content": null,
#         "query": "%23MeMolestaLaGenteQue",
#         "name": "#MeMolestaLaGenteQue"
#       },
#       {
#         "tweet_volume": 11978,
#         "url": "http://twitter.com/search?q=%23QueLoSepaTodoElMundo",
#         "promoted_content": null,
#         "query": "%23QueLoSepaTodoElMundo",
#         "name": "#QueLoSepaTodoElMundo"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23VaiQueColaEp02",
#         "promoted_content": null,
#         "query": "%23VaiQueColaEp02",
#         "name": "#VaiQueColaEp02"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23PremiosACE",
#         "promoted_content": null,
#         "query": "%23PremiosACE",
#         "name": "#PremiosACE"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23%D9%86%D8%B7%D8%A7%D9%84%D8%A8_%D8%A8%D9%85%D8%AD%D8%A7%D8%B3%D8%A8%D9%87_%D8%A7%D9%84%D8%A8%D9%88%D9%8A%D8%A7%D8%AA_%D9%88%D8%A7%D9%84%D8%B4%D9%88%D8%A7%D8%B0",
#         "promoted_content": null,
#         "query": "%23%D9%86%D8%B7%D8%A7%D9%84%D8%A8_%D8%A8%D9%85%D8%AD%D8%A7%D8%B3%D8%A8%D9%87_%D8%A7%D9%84%D8%A8%D9%88%D9%8A%D8%A7%D8%AA_%D9%88%D8%A7%D9%84%D8%B4%D9%88%D8%A7%D8%B0",
#         "name": "#\u0646\u0637\u0627\u0644\u0628_\u0628\u0645\u062d\u0627\u0633\u0628\u0647_\u0627\u0644\u0628\u0648\u064a\u0627\u062a_\u0648\u0627\u0644\u0634\u0648\u0627\u0630"
#       },
#       {
#         "tweet_volume": 38156,
#         "url": "http://twitter.com/search?q=%23TaTaoQuenteQue",
#         "promoted_content": null,
#         "query": "%23TaTaoQuenteQue",
#         "name": "#TaTaoQuenteQue"
#       },
#       {
#         "tweet_volume": 14687,
#         "url": "http://twitter.com/search?q=%23NadieMenos",
#         "promoted_content": null,
#         "query": "%23NadieMenos",
#         "name": "#NadieMenos"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23NataValdebenitoMV",
#         "promoted_content": null,
#         "query": "%23NataValdebenitoMV",
#         "name": "#NataValdebenitoMV"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23SiYoNoFueraTuitero",
#         "promoted_content": null,
#         "query": "%23SiYoNoFueraTuitero",
#         "name": "#SiYoNoFueraTuitero"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23RejectedMovieMonsters",
#         "promoted_content": null,
#         "query": "%23RejectedMovieMonsters",
#         "name": "#RejectedMovieMonsters"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23PreciosaInformante",
#         "promoted_content": null,
#         "query": "%23PreciosaInformante",
#         "name": "#PreciosaInformante"
#       }
#     ],
#     "locations": [
#       {
#         "woeid": 1,
#         "name": "Worldwide"
#       }
#     ]
#   }
# ]

# %%
print (json.dumps(us_trends,indent = 2))
# Out:
# [
#   {
#     "created_at": "2016-10-19T02:35:29Z",
#     "as_of": "2016-10-19T02:38:47Z",
#     "trends": [
#       {
#         "tweet_volume": 69603,
#         "url": "http://twitter.com/search?q=%23SDLive",
#         "promoted_content": null,
#         "query": "%23SDLive",
#         "name": "#SDLive"
#       },
#       {
#         "tweet_volume": 12765,
#         "url": "http://twitter.com/search?q=%22Rich+Hill%22",
#         "promoted_content": null,
#         "query": "%22Rich+Hill%22",
#         "name": "Rich Hill"
#       },
#       {
#         "tweet_volume": 14228,
#         "url": "http://twitter.com/search?q=%23ThisIsUs",
#         "promoted_content": null,
#         "query": "%23ThisIsUs",
#         "name": "#ThisIsUs"
#       },
#       {
#         "tweet_volume": 52613,
#         "url": "http://twitter.com/search?q=%23MTVScreamSpecial",
#         "promoted_content": null,
#         "query": "%23MTVScreamSpecial",
#         "name": "#MTVScreamSpecial"
#       },
#       {
#         "tweet_volume": 20974,
#         "url": "http://twitter.com/search?q=%23ScreamQueens",
#         "promoted_content": null,
#         "query": "%23ScreamQueens",
#         "name": "#ScreamQueens"
#       },
#       {
#         "tweet_volume": 37962,
#         "url": "http://twitter.com/search?q=%23TheFlash",
#         "promoted_content": null,
#         "query": "%23TheFlash",
#         "name": "#TheFlash"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22Paper+Boi%22",
#         "promoted_content": null,
#         "query": "%22Paper+Boi%22",
#         "name": "Paper Boi"
#       },
#       {
#         "tweet_volume": 45041,
#         "url": "http://twitter.com/search?q=PSAT",
#         "promoted_content": null,
#         "query": "PSAT",
#         "name": "PSAT"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22Joe+Blanton%22",
#         "promoted_content": null,
#         "query": "%22Joe+Blanton%22",
#         "name": "Joe Blanton"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22Marian+Hossa%22",
#         "promoted_content": null,
#         "query": "%22Marian+Hossa%22",
#         "name": "Marian Hossa"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=Soler",
#         "promoted_content": null,
#         "query": "Soler",
#         "name": "Soler"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22Knuck+If+You+Buck%22",
#         "promoted_content": null,
#         "query": "%22Knuck+If+You+Buck%22",
#         "name": "Knuck If You Buck"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22Taylor+Hall%22",
#         "promoted_content": null,
#         "query": "%22Taylor+Hall%22",
#         "name": "Taylor Hall"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22Matt+Read%22",
#         "promoted_content": null,
#         "query": "%22Matt+Read%22",
#         "name": "Matt Read"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=Stamkos",
#         "promoted_content": null,
#         "query": "Stamkos",
#         "name": "Stamkos"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22Spirit+Squad%22",
#         "promoted_content": null,
#         "query": "%22Spirit+Squad%22",
#         "name": "Spirit Squad"
#       },
#       {
#         "tweet_volume": 279428,
#         "url": "http://twitter.com/search?q=%23DrainTheSwamp",
#         "promoted_content": null,
#         "query": "%23DrainTheSwamp",
#         "name": "#DrainTheSwamp"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23PhiSlamaJama",
#         "promoted_content": null,
#         "query": "%23PhiSlamaJama",
#         "name": "#PhiSlamaJama"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23ChicagoFire",
#         "promoted_content": null,
#         "query": "%23ChicagoFire",
#         "name": "#ChicagoFire"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23IStayHappyBy",
#         "promoted_content": null,
#         "query": "%23IStayHappyBy",
#         "name": "#IStayHappyBy"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23IfLovingYouIsWrong",
#         "promoted_content": null,
#         "query": "%23IfLovingYouIsWrong",
#         "name": "#IfLovingYouIsWrong"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23TheProfit",
#         "promoted_content": null,
#         "query": "%23TheProfit",
#         "name": "#TheProfit"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23widebate",
#         "promoted_content": null,
#         "query": "%23widebate",
#         "name": "#widebate"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23RejectedMovieMonsters",
#         "promoted_content": null,
#         "query": "%23RejectedMovieMonsters",
#         "name": "#RejectedMovieMonsters"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23Blowhard100",
#         "promoted_content": null,
#         "query": "%23Blowhard100",
#         "name": "#Blowhard100"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23BelowDeck",
#         "promoted_content": null,
#         "query": "%23BelowDeck",
#         "name": "#BelowDeck"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23DanceMoms",
#         "promoted_content": null,
#         "query": "%23DanceMoms",
#         "name": "#DanceMoms"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23statedinner",
#         "promoted_content": null,
#         "query": "%23statedinner",
#         "name": "#statedinner"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23MarriedAtFirstSight",
#         "promoted_content": null,
#         "query": "%23MarriedAtFirstSight",
#         "name": "#MarriedAtFirstSight"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23wppregame",
#         "promoted_content": null,
#         "query": "%23wppregame",
#         "name": "#wppregame"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23CarBooks",
#         "promoted_content": null,
#         "query": "%23CarBooks",
#         "name": "#CarBooks"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23InkMaster",
#         "promoted_content": null,
#         "query": "%23InkMaster",
#         "name": "#InkMaster"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23lasen",
#         "promoted_content": null,
#         "query": "%23lasen",
#         "name": "#lasen"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23ADEchat",
#         "promoted_content": null,
#         "query": "%23ADEchat",
#         "name": "#ADEchat"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23ChrisleyKnowsBest",
#         "promoted_content": null,
#         "query": "%23ChrisleyKnowsBest",
#         "name": "#ChrisleyKnowsBest"
#       },
#       {
#         "tweet_volume": 10598,
#         "url": "http://twitter.com/search?q=%23MakeASongDairy",
#         "promoted_content": null,
#         "query": "%23MakeASongDairy",
#         "name": "#MakeASongDairy"
#       },
#       {
#         "tweet_volume": 280541,
#         "url": "http://twitter.com/search?q=%23AWLMusicVideo",
#         "promoted_content": null,
#         "query": "%23AWLMusicVideo",
#         "name": "#AWLMusicVideo"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23FLAvsTBL",
#         "promoted_content": null,
#         "query": "%23FLAvsTBL",
#         "name": "#FLAvsTBL"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23CapsAvs",
#         "promoted_content": null,
#         "query": "%23CapsAvs",
#         "name": "#CapsAvs"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23DemAgents",
#         "promoted_content": null,
#         "query": "%23DemAgents",
#         "name": "#DemAgents"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23GaryOwenBET",
#         "promoted_content": null,
#         "query": "%23GaryOwenBET",
#         "name": "#GaryOwenBET"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23TrumpLand",
#         "promoted_content": null,
#         "query": "%23TrumpLand",
#         "name": "#TrumpLand"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23DALvsNSH",
#         "promoted_content": null,
#         "query": "%23DALvsNSH",
#         "name": "#DALvsNSH"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23IPSonBET",
#         "promoted_content": null,
#         "query": "%23IPSonBET",
#         "name": "#IPSonBET"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23NCISNOLA",
#         "promoted_content": null,
#         "query": "%23NCISNOLA",
#         "name": "#NCISNOLA"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23HipHopEd",
#         "promoted_content": null,
#         "query": "%23HipHopEd",
#         "name": "#HipHopEd"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23INSen",
#         "promoted_content": null,
#         "query": "%23INSen",
#         "name": "#INSen"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23NoTicketNoSkates",
#         "promoted_content": null,
#         "query": "%23NoTicketNoSkates",
#         "name": "#NoTicketNoSkates"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23concluVZLA",
#         "promoted_content": null,
#         "query": "%23concluVZLA",
#         "name": "#concluVZLA"
#       }
#     ],
#     "locations": [
#       {
#         "woeid": 23424977,
#         "name": "United States"
#       }
#     ]
#   }
# ]

# %%
print (json.dumps(india_trends,indent = 2))
# Out:
# [
#   {
#     "created_at": "2016-10-19T02:30:29Z",
#     "as_of": "2016-10-19T02:38:48Z",
#     "trends": [
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23KarwaChauth",
#         "promoted_content": null,
#         "query": "%23KarwaChauth",
#         "name": "#KarwaChauth"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23EnoughInjustice",
#         "promoted_content": null,
#         "query": "%23EnoughInjustice",
#         "name": "#EnoughInjustice"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%229+Days+To+Shivaay%22",
#         "promoted_content": null,
#         "query": "%229+Days+To+Shivaay%22",
#         "name": "9 Days To Shivaay"
#       },
#       {
#         "tweet_volume": 69105,
#         "url": "http://twitter.com/search?q=%23SDLive",
#         "promoted_content": null,
#         "query": "%23SDLive",
#         "name": "#SDLive"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=Baramulla",
#         "promoted_content": null,
#         "query": "Baramulla",
#         "name": "Baramulla"
#       },
#       {
#         "tweet_volume": 283637,
#         "url": "http://twitter.com/search?q=%23AmazingLionHeart",
#         "promoted_content": null,
#         "query": "%23AmazingLionHeart",
#         "name": "#AmazingLionHeart"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23GSTCouncil",
#         "promoted_content": null,
#         "query": "%23GSTCouncil",
#         "name": "#GSTCouncil"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22Skult+With+Shahid%22",
#         "promoted_content": null,
#         "query": "%22Skult+With+Shahid%22",
#         "name": "Skult With Shahid"
#       },
#       {
#         "tweet_volume": 19588,
#         "url": "http://twitter.com/search?q=Ludhiana",
#         "promoted_content": null,
#         "query": "Ludhiana",
#         "name": "Ludhiana"
#       },
#       {
#         "tweet_volume": 19620,
#         "url": "http://twitter.com/search?q=%22Karan+Johar%22",
#         "promoted_content": null,
#         "query": "%22Karan+Johar%22",
#         "name": "Karan Johar"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22Smriti+Irani%22",
#         "promoted_content": null,
#         "query": "%22Smriti+Irani%22",
#         "name": "Smriti Irani"
#       },
#       {
#         "tweet_volume": 15417,
#         "url": "http://twitter.com/search?q=%222+DAYS+TO+DANGAL+TRAILER%22",
#         "promoted_content": null,
#         "query": "%222+DAYS+TO+DANGAL+TRAILER%22",
#         "name": "2 DAYS TO DANGAL TRAILER"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22Mukesh+Ambani%22",
#         "promoted_content": null,
#         "query": "%22Mukesh+Ambani%22",
#         "name": "Mukesh Ambani"
#       },
#       {
#         "tweet_volume": 158960,
#         "url": "http://twitter.com/search?q=Mosul",
#         "promoted_content": null,
#         "query": "Mosul",
#         "name": "Mosul"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=Ayodhya",
#         "promoted_content": null,
#         "query": "Ayodhya",
#         "name": "Ayodhya"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22INS+Arihant%22",
#         "promoted_content": null,
#         "query": "%22INS+Arihant%22",
#         "name": "INS Arihant"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22Suresh+Raina%22",
#         "promoted_content": null,
#         "query": "%22Suresh+Raina%22",
#         "name": "Suresh Raina"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%22India%27s+NSG%22",
#         "promoted_content": null,
#         "query": "%22India%27s+NSG%22",
#         "name": "India's NSG"
#       },
#       {
#         "tweet_volume": 295431,
#         "url": "http://twitter.com/search?q=Group",
#         "promoted_content": null,
#         "query": "Group",
#         "name": "Group"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23Mohini",
#         "promoted_content": null,
#         "query": "%23Mohini",
#         "name": "#Mohini"
#       },
#       {
#         "tweet_volume": 22157,
#         "url": "http://twitter.com/search?q=%23DilDekeDekhoOnSAB",
#         "promoted_content": null,
#         "query": "%23DilDekeDekhoOnSAB",
#         "name": "#DilDekeDekhoOnSAB"
#       },
#       {
#         "tweet_volume": 21694,
#         "url": "http://twitter.com/search?q=%23MII2016",
#         "promoted_content": null,
#         "query": "%23MII2016",
#         "name": "#MII2016"
#       },
#       {
#         "tweet_volume": 13848,
#         "url": "http://twitter.com/search?q=%23SmileToImpress",
#         "promoted_content": null,
#         "query": "%23SmileToImpress",
#         "name": "#SmileToImpress"
#       },
#       {
#         "tweet_volume": 37818,
#         "url": "http://twitter.com/search?q=%23DearZindagiFirstLook",
#         "promoted_content": null,
#         "query": "%23DearZindagiFirstLook",
#         "name": "#DearZindagiFirstLook"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23KeepItorLetItGo",
#         "promoted_content": null,
#         "query": "%23KeepItorLetItGo",
#         "name": "#KeepItorLetItGo"
#       },
#       {
#         "tweet_volume": 16952,
#         "url": "http://twitter.com/search?q=%23ModiInPunjab",
#         "promoted_content": null,
#         "query": "%23ModiInPunjab",
#         "name": "#ModiInPunjab"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23TurnHimOn",
#         "promoted_content": null,
#         "query": "%23TurnHimOn",
#         "name": "#TurnHimOn"
#       },
#       {
#         "tweet_volume": 38712,
#         "url": "http://twitter.com/search?q=%23CleanChit_InFakeRapeCase",
#         "promoted_content": null,
#         "query": "%23CleanChit_InFakeRapeCase",
#         "name": "#CleanChit_InFakeRapeCase"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23InduSarkar",
#         "promoted_content": null,
#         "query": "%23InduSarkar",
#         "name": "#InduSarkar"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23PMPadhaoDeshBachao",
#         "promoted_content": null,
#         "query": "%23PMPadhaoDeshBachao",
#         "name": "#PMPadhaoDeshBachao"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23ThinkInsideTheBox",
#         "promoted_content": null,
#         "query": "%23ThinkInsideTheBox",
#         "name": "#ThinkInsideTheBox"
#       },
#       {
#         "tweet_volume": 10190,
#         "url": "http://twitter.com/search?q=%234GoldenYearsOfVarunDhawan",
#         "promoted_content": null,
#         "query": "%234GoldenYearsOfVarunDhawan",
#         "name": "#4GoldenYearsOfVarunDhawan"
#       },
#       {
#         "tweet_volume": 35011,
#         "url": "http://twitter.com/search?q=%23Bhubaneswar",
#         "promoted_content": null,
#         "query": "%23Bhubaneswar",
#         "name": "#Bhubaneswar"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23Kahaani2",
#         "promoted_content": null,
#         "query": "%23Kahaani2",
#         "name": "#Kahaani2"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23MandirPolitics",
#         "promoted_content": null,
#         "query": "%23MandirPolitics",
#         "name": "#MandirPolitics"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23DELvMUM",
#         "promoted_content": null,
#         "query": "%23DELvMUM",
#         "name": "#DELvMUM"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23SapneHueBade",
#         "promoted_content": null,
#         "query": "%23SapneHueBade",
#         "name": "#SapneHueBade"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23INDvENG",
#         "promoted_content": null,
#         "query": "%23INDvENG",
#         "name": "#INDvENG"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23VentilatorTrailer",
#         "promoted_content": null,
#         "query": "%23VentilatorTrailer",
#         "name": "#VentilatorTrailer"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23BB10",
#         "promoted_content": null,
#         "query": "%23BB10",
#         "name": "#BB10"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23IromSharmila",
#         "promoted_content": null,
#         "query": "%23IromSharmila",
#         "name": "#IromSharmila"
#       },
#       {
#         "tweet_volume": 17212,
#         "url": "http://twitter.com/search?q=%23LIVMUN",
#         "promoted_content": null,
#         "query": "%23LIVMUN",
#         "name": "#LIVMUN"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23JusticeforRudresh",
#         "promoted_content": null,
#         "query": "%23JusticeforRudresh",
#         "name": "#JusticeforRudresh"
#       },
#       {
#         "tweet_volume": null,
#         "url": "http://twitter.com/search?q=%23Vijay61",
#         "promoted_content": null,
#         "query": "%23Vijay61",
#         "name": "#Vijay61"
#       }
#     ],
#     "locations": [
#       {
#         "woeid": 23424848,
#         "name": "India"
#       }
#     ]
#   }
# ]

# %%
from prettytable import PrettyTable

# %%
world_trends = [i['name'] for i in world_trends[0]['trends']]

# %%
print (world_trends)
# Out:
# ['#MasterChefBR', 'Luciano Castro', '#SDLive', '#ManosalFuego', '#MTVScreamSpecial', '#FreixoNaRedeTV', 'Rich Hill', 'Caniggia', 'Bruna Marquezine', '이자혜', 'Dia de Grêmio', 'Premonição 5', 'PSAT', 'Paper Boi', '#Supermax', '#ContactoConMaduro70', '#MOPnaFMODia', '#MartesIntratable', '#MusicaBoaAoVivo', '#Limite6GH17', '#YoAmoLaFriendZone', '#NoWayVideoClipe', '#LadyCuernos', '#AWLMusicVideo', '#DrainTheSwamp', '#اسامح_كل_شخص_الا_اللي', '#بكل_اختصار', '#concluVZLA', '#IStayHappyBy', '#QuieroSaberEPN', '#PhiSlamaJama', '#احلي_كلمه_علي_قلبك', '#AganarConNitantukkySeguidores', '#DesafioSuperHumanos', '#GrietaSocial', '#VoteAnittaClipeTVZ', '#شي_تتمناه_لنفسك', '#ShawmilaAppreciation', '#TalkingSmack', '#MeMolestaLaGenteQue', '#QueLoSepaTodoElMundo', '#VaiQueColaEp02', '#PremiosACE', '#نطالب_بمحاسبه_البويات_والشواذ', '#TaTaoQuenteQue', '#NadieMenos', '#NataValdebenitoMV', '#SiYoNoFueraTuitero', '#RejectedMovieMonsters', '#PreciosaInformante']

# %%
us_trends = [i['name'] for i in us_trends[0]['trends']]

# %%
print (us_trends)
# Out:
# ['#SDLive', 'Rich Hill', '#ThisIsUs', '#MTVScreamSpecial', '#ScreamQueens', '#TheFlash', 'Paper Boi', 'PSAT', 'Joe Blanton', 'Marian Hossa', 'Soler', 'Knuck If You Buck', 'Taylor Hall', 'Matt Read', 'Stamkos', 'Spirit Squad', '#DrainTheSwamp', '#PhiSlamaJama', '#ChicagoFire', '#IStayHappyBy', '#IfLovingYouIsWrong', '#TheProfit', '#widebate', '#RejectedMovieMonsters', '#Blowhard100', '#BelowDeck', '#DanceMoms', '#statedinner', '#MarriedAtFirstSight', '#wppregame', '#CarBooks', '#InkMaster', '#lasen', '#ADEchat', '#ChrisleyKnowsBest', '#MakeASongDairy', '#AWLMusicVideo', '#FLAvsTBL', '#CapsAvs', '#DemAgents', '#GaryOwenBET', '#TrumpLand', '#DALvsNSH', '#IPSonBET', '#NCISNOLA', '#HipHopEd', '#INSen', '#NoTicketNoSkates', '#concluVZLA']

# %%
india_trends = [i['name'] for i in india_trends[0]['trends']]

# %%
print(india_trends)
# Out:
# ['#KarwaChauth', '#EnoughInjustice', '9 Days To Shivaay', '#SDLive', 'Baramulla', '#AmazingLionHeart', '#GSTCouncil', 'Skult With Shahid', 'Ludhiana', 'Karan Johar', 'Smriti Irani', '2 DAYS TO DANGAL TRAILER', 'Mukesh Ambani', 'Mosul', 'Ayodhya', 'INS Arihant', 'Suresh Raina', "India's NSG", 'Group', '#Mohini', '#DilDekeDekhoOnSAB', '#MII2016', '#SmileToImpress', '#DearZindagiFirstLook', '#KeepItorLetItGo', '#ModiInPunjab', '#TurnHimOn', '#CleanChit_InFakeRapeCase', '#InduSarkar', '#PMPadhaoDeshBachao', '#ThinkInsideTheBox', '#4GoldenYearsOfVarunDhawan', '#Bhubaneswar', '#Kahaani2', '#MandirPolitics', '#DELvMUM', '#SapneHueBade', '#INDvENG', '#VentilatorTrailer', '#BB10', '#IromSharmila', '#LIVMUN', '#JusticeforRudresh', '#Vijay61']

# %%
pt = PrettyTable(field_names = ['World Trends','US Trends','India Trends'])

# %%
for world_trend,us_trend,india_trend in zip(world_trends,us_trends,india_trends):
    pt.add_row([world_trend,us_trend,india_trend])

# %% [markdown]
# So here we are interested in looking the name of the trends in a table format so that it is more viable to study on it.

# %%
print (pt)
# Out:
# +--------------------------------+------------------------+----------------------------+
# |          World Trends          |       US Trends        |        India Trends        |
# +--------------------------------+------------------------+----------------------------+
# |         #MasterChefBR          |        #SDLive         |        #KarwaChauth        |
# |         Luciano Castro         |       Rich Hill        |      #EnoughInjustice      |
# |            #SDLive             |       #ThisIsUs        |     9 Days To Shivaay      |
# |         #ManosalFuego          |   #MTVScreamSpecial    |          #SDLive           |
# |       #MTVScreamSpecial        |     #ScreamQueens      |         Baramulla          |
# |        #FreixoNaRedeTV         |       #TheFlash        |     #AmazingLionHeart      |
# |           Rich Hill            |       Paper Boi        |        #GSTCouncil         |
# |            Caniggia            |          PSAT          |     Skult With Shahid      |
# |        Bruna Marquezine        |      Joe Blanton       |          Ludhiana          |
# |             이자혜             |      Marian Hossa      |        Karan Johar         |
# |         Dia de Grêmio          |         Soler          |        Smriti Irani        |
# |          Premonição 5          |   Knuck If You Buck    |  2 DAYS TO DANGAL TRAILER  |
# |              PSAT              |      Taylor Hall       |       Mukesh Ambani        |
# |           Paper Boi            |       Matt Read        |           Mosul            |
# |           #Supermax            |        Stamkos         |          Ayodhya           |
# |      #ContactoConMaduro70      |      Spirit Squad      |        INS Arihant         |
# |          #MOPnaFMODia          |     #DrainTheSwamp     |        Suresh Raina        |
# |       #MartesIntratable        |     #PhiSlamaJama      |        India's NSG         |
# |        #MusicaBoaAoVivo        |      #ChicagoFire      |           Group            |
# |          #Limite6GH17          |     #IStayHappyBy      |          #Mohini           |
# |       #YoAmoLaFriendZone       |  #IfLovingYouIsWrong   |     #DilDekeDekhoOnSAB     |
# |        #NoWayVideoClipe        |       #TheProfit       |          #MII2016          |
# |          #LadyCuernos          |       #widebate        |      #SmileToImpress       |
# |         #AWLMusicVideo         | #RejectedMovieMonsters |   #DearZindagiFirstLook    |
# |         #DrainTheSwamp         |      #Blowhard100      |      #KeepItorLetItGo      |
# |     #اسامح_كل_شخص_الا_اللي     |       #BelowDeck       |       #ModiInPunjab        |
# |          #بكل_اختصار           |       #DanceMoms       |         #TurnHimOn         |
# |          #concluVZLA           |      #statedinner      | #CleanChit_InFakeRapeCase  |
# |         #IStayHappyBy          |  #MarriedAtFirstSight  |        #InduSarkar         |
# |        #QuieroSaberEPN         |       #wppregame       |    #PMPadhaoDeshBachao     |
# |         #PhiSlamaJama          |       #CarBooks        |     #ThinkInsideTheBox     |
# |      #احلي_كلمه_علي_قلبك       |       #InkMaster       | #4GoldenYearsOfVarunDhawan |
# | #AganarConNitantukkySeguidores |         #lasen         |        #Bhubaneswar        |
# |      #DesafioSuperHumanos      |        #ADEchat        |         #Kahaani2          |
# |         #GrietaSocial          |   #ChrisleyKnowsBest   |      #MandirPolitics       |
# |      #VoteAnittaClipeTVZ       |    #MakeASongDairy     |          #DELvMUM          |
# |        #شي_تتمناه_لنفسك        |     #AWLMusicVideo     |       #SapneHueBade        |
# |     #ShawmilaAppreciation      |       #FLAvsTBL        |          #INDvENG          |
# |         #TalkingSmack          |        #CapsAvs        |     #VentilatorTrailer     |
# |      #MeMolestaLaGenteQue      |       #DemAgents       |           #BB10            |
# |     #QueLoSepaTodoElMundo      |      #GaryOwenBET      |       #IromSharmila        |
# |        #VaiQueColaEp02         |       #TrumpLand       |          #LIVMUN           |
# |          #PremiosACE           |       #DALvsNSH        |     #JusticeforRudresh     |
# | #نطالب_بمحاسبه_البويات_والشواذ |       #IPSonBET        |          #Vijay61          |
# +--------------------------------+------------------------+----------------------------+

# %% [markdown]
# Now we are interested in knowing the common trends going on!
# for that we use set intersection.

# %%
set(world_trends).intersection(set(us_trends))
# Out:
# {'#AWLMusicVideo',
#  '#DrainTheSwamp',
#  '#IStayHappyBy',
#  '#MTVScreamSpecial',
#  '#PhiSlamaJama',
#  '#RejectedMovieMonsters',
#  '#SDLive',
#  '#concluVZLA',
#  'PSAT',
#  'Paper Boi',
#  'Rich Hill'}

# %%
set(world_trends).intersection(set(india_trends))
# Out:
# {'#SDLive'}

# %%
set(us_trends).intersection(set(india_trends))
# Out:
# {'#SDLive'}

# %% [markdown]
# so we noticed some of the trending topics are commonly going in the world and the countries but there is no common trend between india and US right now.

# %%
query = 'IndiaPakistan'
count = 100
search_results = twitter_api.search.tweets(q=query ,count=count)

# %%
print (json.dumps(search_results,indent = 2))
# Out:
# {
#   "search_metadata": {
#     "count": 100,
#     "completed_in": 0.113,
#     "max_id": 788300050837278720,
#     "since_id_str": "0",
#     "refresh_url": "?since_id=788300050837278720&q=IndiaPakistan&include_entities=1",
#     "since_id": 0,
#     "query": "IndiaPakistan",
#     "next_results": "?max_id=786104397763928063&q=IndiaPakistan&count=100&include_entities=1",
#     "max_id_str": "788300050837278720"
#   },
#   "statuses": [
#     {
#       "favorited": false,
#       "favorite_count": 0,
#       "place": null,
#       "retweet_count": 2,
#       "is_quote_status": false,
#       "coordinates": null,
#       "lang": "en",
#       "entities": {
#         "hashtags": [
#           {
#             "indices": [
#               117,
#               131
#             ],
#             "text": "IndiaPakistan"
#           }
#         ],
#         "urls": [],
#         "symbols": [],
#         "user_mentions": [
#           {
#             "indices": [
#               3,
#               13
#             ],
#             "name": "Anu Tomar",
#             "id_str": "768396071097737216",
#             "id": 768396071097737216,
#             "screen_name": "iam_anu12"
#           }
#         ]
#       },
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_status_id": null,
#       "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#       "created_at": "Tue Oct 18 08:45:52 +0000 2016",
#       "contributors": null,
#       "in_reply_to_screen_name": null,
#       "id_str": "788300050837278720",
#       "retweeted_status": {
#         "favorited": false,
#         "favorite_count": 2,
#         "place": null,
#         "retweet_count": 2,
#         "coordinates": null,
#         "lang": "en",
#         "entities": {
#           "hashtags": [
#             {
#               "indices": [
#                 102,
#                 116
#               ],
#               "text": "IndiaPakistan"
#             }
#           ],
#           "urls": [],
#           "symbols": [],
#           "user_mentions": []
#         },
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_status_id": null,
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "created_at": "Tue Oct 18 08:37:07 +0000 2016",
#         "contributors": null,
#         "in_reply_to_screen_name": null,
#         "id_str": "788297848274026496",
#         "is_quote_status": false,
#         "metadata": {
#           "iso_language_code": "en",
#           "result_type": "recent"
#         },
#         "in_reply_to_status_id_str": null,
#         "retweeted": false,
#         "user": {
#           "notifications": false,
#           "profile_use_background_image": true,
#           "profile_image_url_https": "https://pbs.twimg.com/profile_images/781095000352227328/AsGPF9Pv_normal.jpg",
#           "profile_sidebar_border_color": "C0DEED",
#           "profile_image_url": "http://pbs.twimg.com/profile_images/781095000352227328/AsGPF9Pv_normal.jpg",
#           "profile_background_image_url_https": null,
#           "follow_request_sent": false,
#           "protected": false,
#           "is_translation_enabled": false,
#           "has_extended_profile": true,
#           "screen_name": "iam_anu12",
#           "entities": {
#             "description": {
#               "urls": []
#             },
#             "url": {
#               "urls": [
#                 {
#                   "indices": [
#                     0,
#                     23
#                   ],
#                   "display_url": "theconstantinconstant.blogspot.com",
#                   "expanded_url": "http://theconstantinconstant.blogspot.com",
#                   "url": "https://t.co/o8Qj5ZQ3Ma"
#                 }
#               ]
#             }
#           },
#           "profile_sidebar_fill_color": "DDEEF6",
#           "profile_background_tile": false,
#           "followers_count": 77,
#           "time_zone": "Pacific Time (US & Canada)",
#           "contributors_enabled": false,
#           "location": "",
#           "following": false,
#           "profile_background_image_url": null,
#           "verified": false,
#           "lang": "en-gb",
#           "profile_banner_url": "https://pbs.twimg.com/profile_banners/768396071097737216/1474976123",
#           "utc_offset": -25200,
#           "created_at": "Wed Aug 24 10:34:34 +0000 2016",
#           "profile_text_color": "333333",
#           "url": "https://t.co/o8Qj5ZQ3Ma",
#           "favourites_count": 243,
#           "profile_link_color": "2B7BB9",
#           "statuses_count": 402,
#           "is_translator": false,
#           "listed_count": 3,
#           "geo_enabled": false,
#           "friends_count": 99,
#           "default_profile_image": false,
#           "profile_background_color": "F5F8FA",
#           "translator_type": "none",
#           "default_profile": true,
#           "description": "A global citizen|Nationalist|Feminist but not Misandrist|Proud Indian|\u201cDemocracy and dialogue\u201d is only for those who swear loyalty to the Indian Constitution.",
#           "id_str": "768396071097737216",
#           "id": 768396071097737216,
#           "name": "Anu Tomar"
#         },
#         "text": "The 2 neighbors shared so much history &amp; culture but I think we've reached a saturation point now #IndiaPakistan",
#         "geo": null,
#         "id": 788297848274026496,
#         "truncated": false
#       },
#       "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#       },
#       "in_reply_to_status_id_str": null,
#       "retweeted": false,
#       "user": {
#         "notifications": false,
#         "profile_use_background_image": true,
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/784247211152412672/qyMN3Eo7_normal.jpg",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/784247211152412672/qyMN3Eo7_normal.jpg",
#         "profile_background_image_url_https": null,
#         "follow_request_sent": false,
#         "protected": false,
#         "is_translation_enabled": false,
#         "has_extended_profile": true,
#         "screen_name": "HimalaySingh93",
#         "entities": {
#           "description": {
#             "urls": []
#           }
#         },
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_background_tile": false,
#         "followers_count": 320,
#         "time_zone": null,
#         "contributors_enabled": false,
#         "location": "Meerut, India",
#         "following": false,
#         "profile_background_image_url": null,
#         "verified": false,
#         "lang": "en",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/755097296103170048/1470023315",
#         "utc_offset": null,
#         "created_at": "Mon Jul 18 17:49:59 +0000 2016",
#         "profile_text_color": "333333",
#         "url": null,
#         "favourites_count": 24517,
#         "profile_link_color": "2B7BB9",
#         "statuses_count": 22507,
#         "is_translator": false,
#         "listed_count": 32,
#         "geo_enabled": false,
#         "friends_count": 453,
#         "default_profile_image": false,
#         "profile_background_color": "F5F8FA",
#         "translator_type": "none",
#         "default_profile": true,
#         "description": "",
#         "id_str": "755097296103170048",
#         "id": 755097296103170048,
#         "name": "Himalay Singh"
#       },
#       "text": "RT @iam_anu12: The 2 neighbors shared so much history &amp; culture but I think we've reached a saturation point now #IndiaPakistan",
#       "geo": null,
#       "id": 788300050837278720,
#       "truncated": false
#     },
#     {
#       "favorited": false,
#       "favorite_count": 0,
#       "place": null,
#       "retweet_count": 2,
#       "is_quote_status": false,
#       "coordinates": null,
#       "lang": "en",
#       "entities": {
#         "hashtags": [
#           {
#             "indices": [
#               117,
#               131
#             ],
#             "text": "IndiaPakistan"
#           }
#         ],
#         "urls": [],
#         "symbols": [],
#         "user_mentions": [
#           {
#             "indices": [
#               3,
#               13
#             ],
#             "name": "Anu Tomar",
#             "id_str": "768396071097737216",
#             "id": 768396071097737216,
#             "screen_name": "iam_anu12"
#           }
#         ]
#       },
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_status_id": null,
#       "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#       "created_at": "Tue Oct 18 08:39:25 +0000 2016",
#       "contributors": null,
#       "in_reply_to_screen_name": null,
#       "id_str": "788298426274295808",
#       "retweeted_status": {
#         "favorited": false,
#         "favorite_count": 2,
#         "place": null,
#         "retweet_count": 2,
#         "coordinates": null,
#         "lang": "en",
#         "entities": {
#           "hashtags": [
#             {
#               "indices": [
#                 102,
#                 116
#               ],
#               "text": "IndiaPakistan"
#             }
#           ],
#           "urls": [],
#           "symbols": [],
#           "user_mentions": []
#         },
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_status_id": null,
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "created_at": "Tue Oct 18 08:37:07 +0000 2016",
#         "contributors": null,
#         "in_reply_to_screen_name": null,
#         "id_str": "788297848274026496",
#         "is_quote_status": false,
#         "metadata": {
#           "iso_language_code": "en",
#           "result_type": "recent"
#         },
#         "in_reply_to_status_id_str": null,
#         "retweeted": false,
#         "user": {
#           "notifications": false,
#           "profile_use_background_image": true,
#           "profile_image_url_https": "https://pbs.twimg.com/profile_images/781095000352227328/AsGPF9Pv_normal.jpg",
#           "profile_sidebar_border_color": "C0DEED",
#           "profile_image_url": "http://pbs.twimg.com/profile_images/781095000352227328/AsGPF9Pv_normal.jpg",
#           "profile_background_image_url_https": null,
#           "follow_request_sent": false,
#           "protected": false,
#           "is_translation_enabled": false,
#           "has_extended_profile": true,
#           "screen_name": "iam_anu12",
#           "entities": {
#             "description": {
#               "urls": []
#             },
#             "url": {
#               "urls": [
#                 {
#                   "indices": [
#                     0,
#                     23
#                   ],
#                   "display_url": "theconstantinconstant.blogspot.com",
#                   "expanded_url": "http://theconstantinconstant.blogspot.com",
#                   "url": "https://t.co/o8Qj5ZQ3Ma"
#                 }
#               ]
#             }
#           },
#           "profile_sidebar_fill_color": "DDEEF6",
#           "profile_background_tile": false,
#           "followers_count": 77,
#           "time_zone": "Pacific Time (US & Canada)",
#           "contributors_enabled": false,
#           "location": "",
#           "following": false,
#           "profile_background_image_url": null,
#           "verified": false,
#           "lang": "en-gb",
#           "profile_banner_url": "https://pbs.twimg.com/profile_banners/768396071097737216/1474976123",
#           "utc_offset": -25200,
#           "created_at": "Wed Aug 24 10:34:34 +0000 2016",
#           "profile_text_color": "333333",
#           "url": "https://t.co/o8Qj5ZQ3Ma",
#           "favourites_count": 243,
#           "profile_link_color": "2B7BB9",
#           "statuses_count": 402,
#           "is_translator": false,
#           "listed_count": 3,
#           "geo_enabled": false,
#           "friends_count": 99,
#           "default_profile_image": false,
#           "profile_background_color": "F5F8FA",
#           "translator_type": "none",
#           "default_profile": true,
#           "description": "A global citizen|Nationalist|Feminist but not Misandrist|Proud Indian|\u201cDemocracy and dialogue\u201d is only for those who swear loyalty to the Indian Constitution.",
#           "id_str": "768396071097737216",
#           "id": 768396071097737216,
#           "name": "Anu Tomar"
#         },
#         "text": "The 2 neighbors shared so much history &amp; culture but I think we've reached a saturation point now #IndiaPakistan",
#         "geo": null,
#         "id": 788297848274026496,
#         "truncated": false
#       },
#       "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#       },
#       "in_reply_to_status_id_str": null,
#       "retweeted": false,
#       "user": {
#         "notifications": false,
#         "profile_use_background_image": false,
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/781413492439953408/WNUBUd4c_normal.jpg",
#         "profile_sidebar_border_color": "000000",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/781413492439953408/WNUBUd4c_normal.jpg",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "follow_request_sent": false,
#         "protected": false,
#         "is_translation_enabled": false,
#         "has_extended_profile": true,
#         "screen_name": "apolina_de",
#         "entities": {
#           "description": {
#             "urls": []
#           }
#         },
#         "profile_sidebar_fill_color": "000000",
#         "profile_background_tile": false,
#         "followers_count": 75,
#         "time_zone": null,
#         "contributors_enabled": false,
#         "location": "\u092e\u0941\u0902\u092c\u0908, \u092d\u093e\u0930\u0924",
#         "following": false,
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "verified": false,
#         "lang": "en-gb",
#         "utc_offset": null,
#         "created_at": "Thu Aug 25 06:45:38 +0000 2016",
#         "profile_text_color": "000000",
#         "url": null,
#         "favourites_count": 110,
#         "profile_link_color": "1B95E0",
#         "statuses_count": 284,
#         "is_translator": false,
#         "listed_count": 1,
#         "geo_enabled": false,
#         "friends_count": 89,
#         "default_profile_image": false,
#         "profile_background_color": "000000",
#         "translator_type": "none",
#         "default_profile": false,
#         "description": "A nationalist, true Indian, partriotism runs in my blood! Follow me only if you could handle sarcasm! All opinions r my own! RTs are not for endorsements!",
#         "id_str": "768700847681314816",
#         "id": 768700847681314816,
#         "name": "Apolina De"
#       },
#       "text": "RT @iam_anu12: The 2 neighbors shared so much history &amp; culture but I think we've reached a saturation point now #IndiaPakistan",
#       "geo": null,
#       "id": 788298426274295808,
#       "truncated": false
#     },
#     {
#       "favorited": false,
#       "favorite_count": 0,
#       "place": null,
#       "retweet_count": 1,
#       "is_quote_status": false,
#       "coordinates": null,
#       "lang": "en",
#       "entities": {
#         "hashtags": [
#           {
#             "indices": [
#               33,
#               41
#             ],
#             "text": "Pigeons"
#           },
#           {
#             "indices": [
#               46,
#               53
#             ],
#             "text": "spying"
#           },
#           {
#             "indices": [
#               58,
#               67
#             ],
#             "text": "security"
#           },
#           {
#             "indices": [
#               80,
#               94
#             ],
#             "text": "IndiaPakistan"
#           }
#         ],
#         "urls": [
#           {
#             "indices": [
#               102,
#               125
#             ],
#             "display_url": "sptnkne.ws/c2AK",
#             "expanded_url": "http://sptnkne.ws/c2AK",
#             "url": "https://t.co/5uUoZvnE68"
#           }
#         ],
#         "symbols": [],
#         "user_mentions": [
#           {
#             "indices": [
#               3,
#               17
#             ],
#             "name": "Sputnik US",
#             "id_str": "115618332",
#             "id": 115618332,
#             "screen_name": "SputnikNewsUS"
#           }
#         ]
#       },
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_status_id": null,
#       "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#       "created_at": "Tue Oct 18 08:37:08 +0000 2016",
#       "contributors": null,
#       "in_reply_to_screen_name": null,
#       "possibly_sensitive": false,
#       "id_str": "788297853630345217",
#       "retweeted_status": {
#         "extended_entities": {
#           "media": [
#             {
#               "type": "animated_gif",
#               "media_url": "http://pbs.twimg.com/tweet_video_thumb/Cu_TLX9XYAAHYiT.jpg",
#               "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/Cu_TLX9XYAAHYiT.jpg",
#               "sizes": {
#                 "medium": {
#                   "h": 210,
#                   "w": 276,
#                   "resize": "fit"
#                 },
#                 "small": {
#                   "h": 210,
#                   "w": 276,
#                   "resize": "fit"
#                 },
#                 "thumb": {
#                   "h": 150,
#                   "w": 150,
#                   "resize": "crop"
#                 },
#                 "large": {
#                   "h": 210,
#                   "w": 276,
#                   "resize": "fit"
#                 }
#               },
#               "video_info": {
#                 "aspect_ratio": [
#                   46,
#                   35
#                 ],
#                 "variants": [
#                   {
#                     "url": "https://pbs.twimg.com/tweet_video/Cu_TLX9XYAAHYiT.mp4",
#                     "bitrate": 0,
#                     "content_type": "video/mp4"
#                   }
#                 ]
#               },
#               "url": "https://t.co/kJArO2Mx5E",
#               "id_str": "788080652176547840",
#               "indices": [
#                 107,
#                 130
#               ],
#               "expanded_url": "https://twitter.com/SputnikNewsUS/status/788296057230798848/photo/1",
#               "id": 788080652176547840,
#               "display_url": "pic.twitter.com/kJArO2Mx5E"
#             }
#           ]
#         },
#         "favorited": false,
#         "favorite_count": 1,
#         "place": null,
#         "retweet_count": 1,
#         "coordinates": null,
#         "lang": "en",
#         "entities": {
#           "media": [
#             {
#               "type": "photo",
#               "media_url": "http://pbs.twimg.com/tweet_video_thumb/Cu_TLX9XYAAHYiT.jpg",
#               "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/Cu_TLX9XYAAHYiT.jpg",
#               "sizes": {
#                 "medium": {
#                   "h": 210,
#                   "w": 276,
#                   "resize": "fit"
#                 },
#                 "small": {
#                   "h": 210,
#                   "w": 276,
#                   "resize": "fit"
#                 },
#                 "thumb": {
#                   "h": 150,
#                   "w": 150,
#                   "resize": "crop"
#                 },
#                 "large": {
#                   "h": 210,
#                   "w": 276,
#                   "resize": "fit"
#                 }
#               },
#               "url": "https://t.co/kJArO2Mx5E",
#               "id_str": "788080652176547840",
#               "indices": [
#                 107,
#                 130
#               ],
#               "expanded_url": "https://twitter.com/SputnikNewsUS/status/788296057230798848/photo/1",
#               "id": 788080652176547840,
#               "display_url": "pic.twitter.com/kJArO2Mx5E"
#             }
#           ],
#           "hashtags": [
#             {
#               "indices": [
#                 14,
#                 22
#               ],
#               "text": "Pigeons"
#             },
#             {
#               "indices": [
#                 27,
#                 34
#               ],
#               "text": "spying"
#             },
#             {
#               "indices": [
#                 39,
#                 48
#               ],
#               "text": "security"
#             },
#             {
#               "indices": [
#                 61,
#                 75
#               ],
#               "text": "IndiaPakistan"
#             }
#           ],
#           "urls": [
#             {
#               "indices": [
#                 83,
#                 106
#               ],
#               "display_url": "sptnkne.ws/c2AK",
#               "expanded_url": "http://sptnkne.ws/c2AK",
#               "url": "https://t.co/5uUoZvnE68"
#             }
#           ],
#           "symbols": [],
#           "user_mentions": []
#         },
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_status_id": null,
#         "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#         "created_at": "Tue Oct 18 08:30:00 +0000 2016",
#         "contributors": null,
#         "in_reply_to_screen_name": null,
#         "possibly_sensitive": false,
#         "id_str": "788296057230798848",
#         "is_quote_status": false,
#         "metadata": {
#           "iso_language_code": "en",
#           "result_type": "recent"
#         },
#         "in_reply_to_status_id_str": null,
#         "retweeted": false,
#         "user": {
#           "notifications": false,
#           "profile_use_background_image": false,
#           "profile_image_url_https": "https://pbs.twimg.com/profile_images/534268273307557889/5hKhSXWP_normal.png",
#           "profile_sidebar_border_color": "FFFFFF",
#           "profile_image_url": "http://pbs.twimg.com/profile_images/534268273307557889/5hKhSXWP_normal.png",
#           "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000114405404/72c9e4c167a027ff41fef5979c12d5f7.jpeg",
#           "follow_request_sent": false,
#           "protected": false,
#           "is_translation_enabled": false,
#           "has_extended_profile": false,
#           "screen_name": "SputnikNewsUS",
#           "entities": {
#             "description": {
#               "urls": []
#             },
#             "url": {
#               "urls": [
#                 {
#                   "indices": [
#                     0,
#                     22
#                   ],
#                   "display_url": "us.sputniknews.com",
#                   "expanded_url": "http://us.sputniknews.com",
#                   "url": "http://t.co/DPxwjqBG4W"
#                 }
#               ]
#             }
#           },
#           "profile_sidebar_fill_color": "F7F7F7",
#           "profile_background_tile": false,
#           "followers_count": 27883,
#           "time_zone": "Eastern Time (US & Canada)",
#           "contributors_enabled": false,
#           "location": "Washington, DC",
#           "following": false,
#           "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000114405404/72c9e4c167a027ff41fef5979c12d5f7.jpeg",
#           "verified": false,
#           "lang": "en",
#           "profile_banner_url": "https://pbs.twimg.com/profile_banners/115618332/1416214468",
#           "utc_offset": -14400,
#           "created_at": "Fri Feb 19 08:55:06 +0000 2010",
#           "profile_text_color": "333333",
#           "url": "http://t.co/DPxwjqBG4W",
#           "favourites_count": 32,
#           "profile_link_color": "FF9600",
#           "statuses_count": 102116,
#           "is_translator": false,
#           "listed_count": 1428,
#           "geo_enabled": false,
#           "friends_count": 3755,
#           "default_profile_image": false,
#           "profile_background_color": "000000",
#           "translator_type": "none",
#           "default_profile": false,
#           "description": "Sputnik is a global wire, radio and digital news service. We exist to tell the stories that aren\u2019t being told.",
#           "id_str": "115618332",
#           "id": 115618332,
#           "name": "Sputnik US"
#         },
#         "text": "Birds of war: #Pigeons are #spying for #security agencies on #IndiaPakistan border https://t.co/5uUoZvnE68 https://t.co/kJArO2Mx5E",
#         "geo": null,
#         "id": 788296057230798848,
#         "truncated": false
#       },
#       "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#       },
#       "in_reply_to_status_id_str": null,
#       "retweeted": false,
#       "user": {
#         "notifications": false,
#         "profile_use_background_image": true,
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1799314685/SfwN58Em_normal",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1799314685/SfwN58Em_normal",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "follow_request_sent": false,
#         "protected": false,
#         "is_translation_enabled": false,
#         "has_extended_profile": false,
#         "screen_name": "johnjoechad",
#         "entities": {
#           "description": {
#             "urls": []
#           }
#         },
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_background_tile": false,
#         "followers_count": 5256,
#         "time_zone": null,
#         "contributors_enabled": false,
#         "location": "",
#         "following": false,
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "verified": false,
#         "lang": "en",
#         "utc_offset": null,
#         "created_at": "Thu Jun 24 12:45:53 +0000 2010",
#         "profile_text_color": "333333",
#         "url": null,
#         "favourites_count": 167578,
#         "profile_link_color": "0084B4",
#         "statuses_count": 370890,
#         "is_translator": false,
#         "listed_count": 706,
#         "geo_enabled": true,
#         "friends_count": 5775,
#         "default_profile_image": false,
#         "profile_background_color": "C0DEED",
#         "translator_type": "none",
#         "default_profile": true,
#         "description": "",
#         "id_str": "159095242",
#         "id": 159095242,
#         "name": "John Finucane"
#       },
#       "text": "RT @SputnikNewsUS: Birds of war: #Pigeons are #spying for #security agencies on #IndiaPakistan border https://t.co/5uUoZvnE68 https://t.co/\u2026",
#       "geo": null,
#       "id": 788297853630345217,
#       "truncated": false
#     },
#     {
#       "favorited": false,
#       "favorite_count": 2,
#       "place": null,
#       "retweet_count": 2,
#       "coordinates": null,
#       "lang": "en",
#       "entities": {
#         "hashtags": [
#           {
#             "indices": [
#               102,
#               116
#             ],
#             "text": "IndiaPakistan"
#           }
#         ],
#         "urls": [],
#         "symbols": [],
#         "user_mentions": []
#       },
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_status_id": null,
#       "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#       "created_at": "Tue Oct 18 08:37:07 +0000 2016",
#       "contributors": null,
#       "in_reply_to_screen_name": null,
#       "id_str": "788297848274026496",
#       "is_quote_status": false,
#       "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#       },
#       "in_reply_to_status_id_str": null,
#       "retweeted": false,
#       "user": {
#         "notifications": false,
#         "profile_use_background_image": true,
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/781095000352227328/AsGPF9Pv_normal.jpg",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/781095000352227328/AsGPF9Pv_normal.jpg",
#         "profile_background_image_url_https": null,
#         "follow_request_sent": false,
#         "protected": false,
#         "is_translation_enabled": false,
#         "has_extended_profile": true,
#         "screen_name": "iam_anu12",
#         "entities": {
#           "description": {
#             "urls": []
#           },
#           "url": {
#             "urls": [
#               {
#                 "indices": [
#                   0,
#                   23
#                 ],
#                 "display_url": "theconstantinconstant.blogspot.com",
#                 "expanded_url": "http://theconstantinconstant.blogspot.com",
#                 "url": "https://t.co/o8Qj5ZQ3Ma"
#               }
#             ]
#           }
#         },
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_background_tile": false,
#         "followers_count": 77,
#         "time_zone": "Pacific Time (US & Canada)",
#         "contributors_enabled": false,
#         "location": "",
#         "following": false,
#         "profile_background_image_url": null,
#         "verified": false,
#         "lang": "en-gb",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/768396071097737216/1474976123",
#         "utc_offset": -25200,
#         "created_at": "Wed Aug 24 10:34:34 +0000 2016",
#         "profile_text_color": "333333",
#         "url": "https://t.co/o8Qj5ZQ3Ma",
#         "favourites_count": 243,
#         "profile_link_color": "2B7BB9",
#         "statuses_count": 402,
#         "is_translator": false,
#         "listed_count": 3,
#         "geo_enabled": false,
#         "friends_count": 99,
#         "default_profile_image": false,
#         "profile_background_color": "F5F8FA",
#         "translator_type": "none",
#         "default_profile": true,
#         "description": "A global citizen|Nationalist|Feminist but not Misandrist|Proud Indian|\u201cDemocracy and dialogue\u201d is only for those who swear loyalty to the Indian Constitution.",
#         "id_str": "768396071097737216",
#         "id": 768396071097737216,
#         "name": "Anu Tomar"
#       },
#       "text": "The 2 neighbors shared so much history &amp; culture but I think we've reached a saturation point now #IndiaPakistan",
#       "geo": null,
#       "id": 788297848274026496,
#       "truncated": false
#     },
#     {
#       "extended_entities": {
#         "media": [
#           {
#             "type": "animated_gif",
#             "media_url": "http://pbs.twimg.com/tweet_video_thumb/Cu_TLX9XYAAHYiT.jpg",
#             "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/Cu_TLX9XYAAHYiT.jpg",
#             "sizes": {
#               "medium": {
#                 "h": 210,
#                 "w": 276,
#                 "resize": "fit"
#               },
#               "small": {
#                 "h": 210,
#                 "w": 276,
#                 "resize": "fit"
#               },
#               "thumb": {
#                 "h": 150,
#                 "w": 150,
#                 "resize": "crop"
#               },
#               "large": {
#                 "h": 210,
#                 "w": 276,
#                 "resize": "fit"
#               }
#             },
#             "video_info": {
#               "aspect_ratio": [
#                 46,
#                 35
#               ],
#               "variants": [
#                 {
#                   "url": "https://pbs.twimg.com/tweet_video/Cu_TLX9XYAAHYiT.mp4",
#                   "bitrate": 0,
#                   "content_type": "video/mp4"
#                 }
#               ]
#             },
#             "url": "https://t.co/kJArO2Mx5E",
#             "id_str": "788080652176547840",
#             "indices": [
#               107,
#               130
#             ],
#             "expanded_url": "https://twitter.com/SputnikNewsUS/status/788296057230798848/photo/1",
#             "id": 788080652176547840,
#             "display_url": "pic.twitter.com/kJArO2Mx5E"
#           }
#         ]
#       },
#       "favorited": false,
#       "favorite_count": 1,
#       "place": null,
#       "retweet_count": 1,
#       "coordinates": null,
#       "lang": "en",
#       "entities": {
#         "media": [
#           {
#             "type": "photo",
#             "media_url": "http://pbs.twimg.com/tweet_video_thumb/Cu_TLX9XYAAHYiT.jpg",
#             "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/Cu_TLX9XYAAHYiT.jpg",
#             "sizes": {
#               "medium": {
#                 "h": 210,
#                 "w": 276,
#                 "resize": "fit"
#               },
#               "small": {
#                 "h": 210,
#                 "w": 276,
#                 "resize": "fit"
#               },
#               "thumb": {
#                 "h": 150,
#                 "w": 150,
#                 "resize": "crop"
#               },
#               "large": {
#                 "h": 210,
#                 "w": 276,
#                 "resize": "fit"
#               }
#             },
#             "url": "https://t.co/kJArO2Mx5E",
#             "id_str": "788080652176547840",
#             "indices": [
#               107,
#               130
#             ],
#             "expanded_url": "https://twitter.com/SputnikNewsUS/status/788296057230798848/photo/1",
#             "id": 788080652176547840,
#             "display_url": "pic.twitter.com/kJArO2Mx5E"
#           }
#         ],
#         "hashtags": [
#           {
#             "indices": [
#               14,
#               22
#             ],
#             "text": "Pigeons"
#           },
#           {
#             "indices": [
#               27,
#               34
#             ],
#             "text": "spying"
#           },
#           {
#             "indices": [
#               39,
#               48
#             ],
#             "text": "security"
#           },
#           {
#             "indices": [
#               61,
#               75
#             ],
#             "text": "IndiaPakistan"
#           }
#         ],
#         "urls": [
#           {
#             "indices": [
#               83,
#               106
#             ],
#             "display_url": "sptnkne.ws/c2AK",
#             "expanded_url": "http://sptnkne.ws/c2AK",
#             "url": "https://t.co/5uUoZvnE68"
#           }
#         ],
#         "symbols": [],
#         "user_mentions": []
#       },
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_status_id": null,
#       "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#       "created_at": "Tue Oct 18 08:30:00 +0000 2016",
#       "contributors": null,
#       "in_reply_to_screen_name": null,
#       "possibly_sensitive": false,
#       "id_str": "788296057230798848",
#       "is_quote_status": false,
#       "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#       },
#       "in_reply_to_status_id_str": null,
#       "retweeted": false,
#       "user": {
#         "notifications": false,
#         "profile_use_background_image": false,
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/534268273307557889/5hKhSXWP_normal.png",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/534268273307557889/5hKhSXWP_normal.png",
#         "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000114405404/72c9e4c167a027ff41fef5979c12d5f7.jpeg",
#         "follow_request_sent": false,
#         "protected": false,
#         "is_translation_enabled": false,
#         "has_extended_profile": false,
#         "screen_name": "SputnikNewsUS",
#         "entities": {
#           "description": {
#             "urls": []
#           },
#           "url": {
#             "urls": [
#               {
#                 "indices": [
#                   0,
#                   22
#                 ],
#                 "display_url": "us.sputniknews.com",
#                 "expanded_url": "http://us.sputniknews.com",
#                 "url": "http://t.co/DPxwjqBG4W"
#               }
#             ]
#           }
#         },
#         "profile_sidebar_fill_color": "F7F7F7",
#         "profile_background_tile": false,
#         "followers_count": 27883,
#         "time_zone": "Eastern Time (US & Canada)",
#         "contributors_enabled": false,
#         "location": "Washington, DC",
#         "following": false,
#         "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000114405404/72c9e4c167a027ff41fef5979c12d5f7.jpeg",
#         "verified": false,
#         "lang": "en",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/115618332/1416214468",
#         "utc_offset": -14400,
#         "created_at": "Fri Feb 19 08:55:06 +0000 2010",
#         "profile_text_color": "333333",
#         "url": "http://t.co/DPxwjqBG4W",
#         "favourites_count": 32,
#         "profile_link_color": "FF9600",
#         "statuses_count": 102116,
#         "is_translator": false,
#         "listed_count": 1428,
#         "geo_enabled": false,
#         "friends_count": 3755,
#         "default_profile_image": false,
#         "profile_background_color": "000000",
#         "translator_type": "none",
#         "default_profile": false,
#         "description": "Sputnik is a global wire, radio and digital news service. We exist to tell the stories that aren\u2019t being told.",
#         "id_str": "115618332",
#         "id": 115618332,
#         "name": "Sputnik US"
#       },
#       "text": "Birds of war: #Pigeons are #spying for #security agencies on #IndiaPakistan border https://t.co/5uUoZvnE68 https://t.co/kJArO2Mx5E",
#       "geo": null,
#       "id": 788296057230798848,
#       "truncated": false
#     },
#     {
#       "favorited": false,
#       "favorite_count": 1,
#       "place": {
#         "country_code": "PK",
#         "full_name": "Sindh, Pakistan",
#         "url": "https://api.twitter.com/1.1/geo/id/0120615153b21abb.json",
#         "bounding_box": {
#           "type": "Polygon",
#           "coordinates": [
#             [
#               [
#                 66.654132,
#                 23.703272
#               ],
#               [
#                 71.124185,
#                 23.703272
#               ],
#               [
#                 71.124185,
#                 28.529442
#               ],
#               [
#                 66.654132,
#                 28.529442
#               ]
#             ]
#           ]
#         },
#         "country": "Pakistan",
#         "contained_within": [],
#         "place_type": "admin",
#         "attributes": {},
#         "id": "0120615153b21abb",
#         "name": "Sindh"
#       },
#       "retweet_count": 0,
#       "coordinates": null,
#       "lang": "en",
#       "entities": {
#         "hashtags": [
#           {
#             "indices": [
#               84,
#               98
#             ],
#             "text": "IndiaPakistan"
#           }
#         ],
#         "urls": [],
#         "symbols": [],
#         "user_mentions": [
#           {
#             "indices": [
#               0,
#               13
#             ],
#             "name": "Aman ki Asha",
#             "id_str": "138093146",
#             "id": 138093146,
#             "screen_name": "amankiasha_1"
#           }
#         ]
#       },
#       "in_reply_to_user_id_str": "138093146",
#       "in_reply_to_user_id": 138093146,
#       "in_reply_to_status_id": null,
#       "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#       "created_at": "Tue Oct 18 05:56:44 +0000 2016",
#       "contributors": null,
#       "in_reply_to_screen_name": "amankiasha_1",
#       "id_str": "788257484607787009",
#       "is_quote_status": false,
#       "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#       },
#       "in_reply_to_status_id_str": null,
#       "retweeted": false,
#       "user": {
#         "notifications": false,
#         "profile_use_background_image": true,
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/772897010433351680/eTlRrnXw_normal.jpg",
#         "profile_sidebar_border_color": "000000",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/772897010433351680/eTlRrnXw_normal.jpg",
#         "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000173022467/4z5MYi_b.jpeg",
#         "follow_request_sent": false,
#         "protected": false,
#         "is_translation_enabled": false,
#         "has_extended_profile": true,
#         "screen_name": "FatimahJaffery",
#         "entities": {
#           "description": {
#             "urls": []
#           },
#           "url": {
#             "urls": [
#               {
#                 "indices": [
#                   0,
#                   23
#                 ],
#                 "display_url": "linkedin.com/in/fatima-jaff\u2026",
#                 "expanded_url": "https://www.linkedin.com/in/fatima-jaffery-56957621",
#                 "url": "https://t.co/FJHb72fFuM"
#               }
#             ]
#           }
#         },
#         "profile_sidebar_fill_color": "F6FFD1",
#         "profile_background_tile": true,
#         "followers_count": 563,
#         "time_zone": "Karachi",
#         "contributors_enabled": false,
#         "location": "Pakistan",
#         "following": false,
#         "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000173022467/4z5MYi_b.jpeg",
#         "verified": false,
#         "lang": "en",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/303909676/1382199341",
#         "utc_offset": 18000,
#         "created_at": "Mon May 23 16:29:39 +0000 2011",
#         "profile_text_color": "333333",
#         "url": "https://t.co/FJHb72fFuM",
#         "favourites_count": 2284,
#         "profile_link_color": "0099CC",
#         "statuses_count": 13264,
#         "is_translator": false,
#         "listed_count": 112,
#         "geo_enabled": true,
#         "friends_count": 2627,
#         "default_profile_image": false,
#         "profile_background_color": "FFF04D",
#         "translator_type": "none",
#         "default_profile": false,
#         "description": "Looking for #Peace, Project Management, Finance background, #lead #motivate\nFundraising & Partnership Director at @Ipadorg Tweets \u2260 Endorsement",
#         "id_str": "303909676",
#         "id": 303909676,
#         "name": "FJ"
#       },
#       "text": "@amankiasha_1 anyone I can speak to at aman ki asha for a program in both countries #IndiaPakistan",
#       "geo": null,
#       "id": 788257484607787009,
#       "truncated": false
#     },
#     {
#       "favorited": false,
#       "favorite_count": 0,
#       "place": null,
#       "retweet_count": 3,
#       "is_quote_status": false,
#       "coordinates": null,
#       "lang": "en",
#       "entities": {
#         "hashtags": [
#           {
#             "indices": [
#               33,
#               41
#             ],
#             "text": "Pigeons"
#           },
#           {
#             "indices": [
#               46,
#               53
#             ],
#             "text": "spying"
#           },
#           {
#             "indices": [
#               58,
#               67
#             ],
#             "text": "security"
#           },
#           {
#             "indices": [
#               80,
#               94
#             ],
#             "text": "IndiaPakistan"
#           }
#         ],
#         "urls": [
#           {
#             "indices": [
#               102,
#               125
#             ],
#             "display_url": "sptnkne.ws/c2AK",
#             "expanded_url": "http://sptnkne.ws/c2AK",
#             "url": "https://t.co/5uUoZv63eA"
#           }
#         ],
#         "symbols": [],
#         "user_mentions": [
#           {
#             "indices": [
#               3,
#               17
#             ],
#             "name": "Sputnik US",
#             "id_str": "115618332",
#             "id": 115618332,
#             "screen_name": "SputnikNewsUS"
#           }
#         ]
#       },
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_status_id": null,
#       "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#       "created_at": "Tue Oct 18 04:37:36 +0000 2016",
#       "contributors": null,
#       "in_reply_to_screen_name": null,
#       "possibly_sensitive": false,
#       "id_str": "788237573529464832",
#       "retweeted_status": {
#         "extended_entities": {
#           "media": [
#             {
#               "type": "animated_gif",
#               "media_url": "http://pbs.twimg.com/tweet_video_thumb/Cu_TIGAWIAAms3U.jpg",
#               "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/Cu_TIGAWIAAms3U.jpg",
#               "sizes": {
#                 "medium": {
#                   "h": 210,
#                   "w": 276,
#                   "resize": "fit"
#                 },
#                 "small": {
#                   "h": 210,
#                   "w": 276,
#                   "resize": "fit"
#                 },
#                 "thumb": {
#                   "h": 150,
#                   "w": 150,
#                   "resize": "crop"
#                 },
#                 "large": {
#                   "h": 210,
#                   "w": 276,
#                   "resize": "fit"
#                 }
#               },
#               "video_info": {
#                 "aspect_ratio": [
#                   46,
#                   35
#                 ],
#                 "variants": [
#                   {
#                     "url": "https://pbs.twimg.com/tweet_video/Cu_TIGAWIAAms3U.mp4",
#                     "bitrate": 0,
#                     "content_type": "video/mp4"
#                   }
#                 ]
#               },
#               "url": "https://t.co/hgrOccSh7V",
#               "id_str": "788080595817603072",
#               "indices": [
#                 107,
#                 130
#               ],
#               "expanded_url": "https://twitter.com/SputnikNewsUS/status/788235658577997824/photo/1",
#               "id": 788080595817603072,
#               "display_url": "pic.twitter.com/hgrOccSh7V"
#             }
#           ]
#         },
#         "favorited": false,
#         "favorite_count": 2,
#         "place": null,
#         "retweet_count": 3,
#         "coordinates": null,
#         "lang": "en",
#         "entities": {
#           "media": [
#             {
#               "type": "photo",
#               "media_url": "http://pbs.twimg.com/tweet_video_thumb/Cu_TIGAWIAAms3U.jpg",
#               "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/Cu_TIGAWIAAms3U.jpg",
#               "sizes": {
#                 "medium": {
#                   "h": 210,
#                   "w": 276,
#                   "resize": "fit"
#                 },
#                 "small": {
#                   "h": 210,
#                   "w": 276,
#                   "resize": "fit"
#                 },
#                 "thumb": {
#                   "h": 150,
#                   "w": 150,
#                   "resize": "crop"
#                 },
#                 "large": {
#                   "h": 210,
#                   "w": 276,
#                   "resize": "fit"
#                 }
#               },
#               "url": "https://t.co/hgrOccSh7V",
#               "id_str": "788080595817603072",
#               "indices": [
#                 107,
#                 130
#               ],
#               "expanded_url": "https://twitter.com/SputnikNewsUS/status/788235658577997824/photo/1",
#               "id": 788080595817603072,
#               "display_url": "pic.twitter.com/hgrOccSh7V"
#             }
#           ],
#           "hashtags": [
#             {
#               "indices": [
#                 14,
#                 22
#               ],
#               "text": "Pigeons"
#             },
#             {
#               "indices": [
#                 27,
#                 34
#               ],
#               "text": "spying"
#             },
#             {
#               "indices": [
#                 39,
#                 48
#               ],
#               "text": "security"
#             },
#             {
#               "indices": [
#                 61,
#                 75
#               ],
#               "text": "IndiaPakistan"
#             }
#           ],
#           "urls": [
#             {
#               "indices": [
#                 83,
#                 106
#               ],
#               "display_url": "sptnkne.ws/c2AK",
#               "expanded_url": "http://sptnkne.ws/c2AK",
#               "url": "https://t.co/5uUoZv63eA"
#             }
#           ],
#           "symbols": [],
#           "user_mentions": []
#         },
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_status_id": null,
#         "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
# ...
#           "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme4/bg.gif",
#           "follow_request_sent": false,
#           "protected": false,
#           "is_translation_enabled": false,
#           "has_extended_profile": true,
#           "screen_name": "sehrish__",
#           "entities": {
#             "description": {
#               "urls": []
#             },
#             "url": {
#               "urls": [
#                 {
#                   "indices": [
#                     0,
#                     23
#                   ],
#                   "display_url": "dailycapital.pk",
#                   "expanded_url": "http://www.dailycapital.pk",
#                   "url": "https://t.co/cWwNRU9k6O"
#                 }
#               ]
#             }
#           },
#           "profile_sidebar_fill_color": "FFFFFF",
#           "profile_background_tile": false,
#           "followers_count": 618,
#           "time_zone": "Karachi",
#           "contributors_enabled": false,
#           "location": "",
#           "following": false,
#           "profile_background_image_url": "http://abs.twimg.com/images/themes/theme4/bg.gif",
#           "verified": false,
#           "lang": "en",
#           "profile_banner_url": "https://pbs.twimg.com/profile_banners/149500211/1476164135",
#           "utc_offset": 18000,
#           "created_at": "Sat May 29 13:01:44 +0000 2010",
#           "profile_text_color": "333333",
#           "url": "https://t.co/cWwNRU9k6O",
#           "favourites_count": 885,
#           "profile_link_color": "009AB9",
#           "statuses_count": 1008,
#           "is_translator": false,
#           "listed_count": 12,
#           "geo_enabled": false,
#           "friends_count": 67,
#           "default_profile_image": false,
#           "profile_background_color": "009AB9",
#           "translator_type": "none",
#           "default_profile": false,
#           "description": "Journalist @CapitalTV_News, Blogger, philanthropist",
#           "id_str": "149500211",
#           "id": 149500211,
#           "name": "Sehrish Salahudin"
#         },
#         "text": "Today's #TopStories With me \n#IndiaPakistan #CPEC #PakChinaFriendship #pakarmy #PMNawaz #COAS #Muharram #Ashura\u2026 https://t.co/Zm6j1a27on",
#         "geo": null,
#         "id": 786079378107170816,
#         "truncated": true
#       },
#       "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#       },
#       "in_reply_to_status_id_str": null,
#       "retweeted": false,
#       "user": {
#         "notifications": false,
#         "profile_use_background_image": true,
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/648053090000568320/mObNNRaS_normal.jpg",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/648053090000568320/mObNNRaS_normal.jpg",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "follow_request_sent": false,
#         "protected": false,
#         "is_translation_enabled": false,
#         "has_extended_profile": false,
#         "screen_name": "naveeda34041840",
#         "entities": {
#           "description": {
#             "urls": []
#           }
#         },
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_background_tile": false,
#         "followers_count": 884,
#         "time_zone": null,
#         "contributors_enabled": false,
#         "location": "Lahore,Pakistan.",
#         "following": false,
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "verified": false,
#         "lang": "en",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/3274967234/1441569245",
#         "utc_offset": null,
#         "created_at": "Fri Jul 10 23:38:34 +0000 2015",
#         "profile_text_color": "333333",
#         "url": null,
#         "favourites_count": 26315,
#         "profile_link_color": "0084B4",
#         "statuses_count": 36979,
#         "is_translator": false,
#         "listed_count": 99,
#         "geo_enabled": true,
#         "friends_count": 139,
#         "default_profile_image": false,
#         "profile_background_color": "C0DEED",
#         "translator_type": "none",
#         "default_profile": true,
#         "description": "",
#         "id_str": "3274967234",
#         "id": 3274967234,
#         "name": "Naveed Asghar."
#       },
#       "text": "RT @sehrish__: Today's #TopStories With me \n#IndiaPakistan #CPEC #PakChinaFriendship #pakarmy #PMNawaz #COAS #Muharram #Ashura #KashmirUnre\u2026",
#       "geo": null,
#       "id": 786125172801699840,
#       "truncated": false
#     },
#     {
#       "favorited": false,
#       "favorite_count": 0,
#       "place": null,
#       "retweet_count": 1,
#       "is_quote_status": false,
#       "coordinates": null,
#       "lang": "en",
#       "entities": {
#         "hashtags": [
#           {
#             "indices": [
#               19,
#               28
#             ],
#             "text": "Pakistan"
#           },
#           {
#             "indices": [
#               47,
#               53
#             ],
#             "text": "China"
#           },
#           {
#             "indices": [
#               65,
#               71
#             ],
#             "text": "India"
#           },
#           {
#             "indices": [
#               75,
#               81
#             ],
#             "text": "SAARC"
#           },
#           {
#             "indices": [
#               82,
#               96
#             ],
#             "text": "IndiaPakistan"
#           }
#         ],
#         "urls": [
#           {
#             "indices": [
#               97,
#               120
#             ],
#             "display_url": "tinyurl.com/h6hngcw",
#             "expanded_url": "http://tinyurl.com/h6hngcw",
#             "url": "https://t.co/7QeBTGkOM9"
#           }
#         ],
#         "symbols": [],
#         "user_mentions": [
#           {
#             "indices": [
#               3,
#               17
#             ],
#             "name": "Odisha News 360",
#             "id_str": "4120312093",
#             "id": 4120312093,
#             "screen_name": "Odishanews360"
#           }
#         ]
#       },
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_status_id": null,
#       "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#       "created_at": "Wed Oct 12 07:21:08 +0000 2016",
#       "contributors": null,
#       "in_reply_to_screen_name": null,
#       "possibly_sensitive": false,
#       "id_str": "786104397763928064",
#       "retweeted_status": {
#         "extended_entities": {
#           "media": [
#             {
#               "type": "photo",
#               "media_url": "http://pbs.twimg.com/media/CujJLWAWcAAU1X-.jpg",
#               "media_url_https": "https://pbs.twimg.com/media/CujJLWAWcAAU1X-.jpg",
#               "sizes": {
#                 "medium": {
#                   "h": 527,
#                   "w": 854,
#                   "resize": "fit"
#                 },
#                 "small": {
#                   "h": 420,
#                   "w": 680,
#                   "resize": "fit"
#                 },
#                 "thumb": {
#                   "h": 150,
#                   "w": 150,
#                   "resize": "crop"
#                 },
#                 "large": {
#                   "h": 527,
#                   "w": 854,
#                   "resize": "fit"
#                 }
#               },
#               "url": "https://t.co/yBGkatCM7W",
#               "id_str": "786099331698946048",
#               "indices": [
#                 102,
#                 125
#               ],
#               "expanded_url": "https://twitter.com/Odishanews360/status/786099398422003713/photo/1",
#               "id": 786099331698946048,
#               "display_url": "pic.twitter.com/yBGkatCM7W"
#             }
#           ]
#         },
#         "favorited": false,
#         "favorite_count": 1,
#         "place": null,
#         "retweet_count": 1,
#         "coordinates": null,
#         "lang": "en",
#         "entities": {
#           "media": [
#             {
#               "type": "photo",
#               "media_url": "http://pbs.twimg.com/media/CujJLWAWcAAU1X-.jpg",
#               "media_url_https": "https://pbs.twimg.com/media/CujJLWAWcAAU1X-.jpg",
#               "sizes": {
#                 "medium": {
#                   "h": 527,
#                   "w": 854,
#                   "resize": "fit"
#                 },
#                 "small": {
#                   "h": 420,
#                   "w": 680,
#                   "resize": "fit"
#                 },
#                 "thumb": {
#                   "h": 150,
#                   "w": 150,
#                   "resize": "crop"
#                 },
#                 "large": {
#                   "h": 527,
#                   "w": 854,
#                   "resize": "fit"
#                 }
#               },
#               "url": "https://t.co/yBGkatCM7W",
#               "id_str": "786099331698946048",
#               "indices": [
#                 102,
#                 125
#               ],
#               "expanded_url": "https://twitter.com/Odishanews360/status/786099398422003713/photo/1",
#               "id": 786099331698946048,
#               "display_url": "pic.twitter.com/yBGkatCM7W"
#             }
#           ],
#           "hashtags": [
#             {
#               "indices": [
#                 0,
#                 9
#               ],
#               "text": "Pakistan"
#             },
#             {
#               "indices": [
#                 28,
#                 34
#               ],
#               "text": "China"
#             },
#             {
#               "indices": [
#                 46,
#                 52
#               ],
#               "text": "India"
#             },
#             {
#               "indices": [
#                 56,
#                 62
#               ],
#               "text": "SAARC"
#             },
#             {
#               "indices": [
#                 63,
#                 77
#               ],
#               "text": "IndiaPakistan"
#             }
#           ],
#           "urls": [
#             {
#               "indices": [
#                 78,
#                 101
#               ],
#               "display_url": "tinyurl.com/h6hngcw",
#               "expanded_url": "http://tinyurl.com/h6hngcw",
#               "url": "https://t.co/7QeBTGkOM9"
#             }
#           ],
#           "symbols": [],
#           "user_mentions": []
#         },
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_status_id": null,
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "created_at": "Wed Oct 12 07:01:16 +0000 2016",
#         "contributors": null,
#         "in_reply_to_screen_name": null,
#         "possibly_sensitive": false,
#         "id_str": "786099398422003713",
#         "is_quote_status": false,
#         "metadata": {
#           "iso_language_code": "en",
#           "result_type": "recent"
#         },
#         "in_reply_to_status_id_str": null,
#         "retweeted": false,
#         "user": {
#           "notifications": false,
#           "profile_use_background_image": true,
#           "profile_image_url_https": "https://pbs.twimg.com/profile_images/686871701192347648/H-i6T5DD_normal.png",
#           "profile_sidebar_border_color": "000000",
#           "profile_image_url": "http://pbs.twimg.com/profile_images/686871701192347648/H-i6T5DD_normal.png",
#           "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme19/bg.gif",
#           "follow_request_sent": false,
#           "protected": false,
#           "is_translation_enabled": false,
#           "has_extended_profile": false,
#           "screen_name": "Odishanews360",
#           "entities": {
#             "description": {
#               "urls": []
#             },
#             "url": {
#               "urls": [
#                 {
#                   "indices": [
#                     0,
#                     23
#                   ],
#                   "display_url": "odishanews360.com",
#                   "expanded_url": "http://www.odishanews360.com",
#                   "url": "https://t.co/WQfengHYPF"
#                 }
#               ]
#             }
#           },
#           "profile_sidebar_fill_color": "000000",
#           "profile_background_tile": false,
#           "followers_count": 242,
#           "time_zone": "Mumbai",
#           "contributors_enabled": false,
#           "location": "",
#           "following": false,
#           "profile_background_image_url": "http://abs.twimg.com/images/themes/theme19/bg.gif",
#           "verified": false,
#           "lang": "en",
#           "profile_banner_url": "https://pbs.twimg.com/profile_banners/4120312093/1452597893",
#           "utc_offset": 19800,
#           "created_at": "Wed Nov 04 04:39:18 +0000 2015",
#           "profile_text_color": "000000",
#           "url": "https://t.co/WQfengHYPF",
#           "favourites_count": 43,
#           "profile_link_color": "3B94D9",
#           "statuses_count": 1956,
#           "is_translator": false,
#           "listed_count": 23,
#           "geo_enabled": false,
#           "friends_count": 63,
#           "default_profile_image": false,
#           "profile_background_color": "FFF04D",
#           "translator_type": "none",
#           "default_profile": false,
#           "description": "Be the 1st to know whats happening in Odisha. Odisha News 360 is an exclusive portal for Odisha state news and happenings.",
#           "id_str": "4120312093",
#           "id": 4120312093,
#           "name": "Odisha News 360"
#         },
#         "text": "#Pakistan Trying To Rope In #China To Counter #India At #SAARC #IndiaPakistan\nhttps://t.co/7QeBTGkOM9 https://t.co/yBGkatCM7W",
#         "geo": null,
#         "id": 786099398422003713,
#         "truncated": false
#       },
#       "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#       },
#       "in_reply_to_status_id_str": null,
#       "retweeted": false,
#       "user": {
#         "notifications": false,
#         "profile_use_background_image": true,
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/780246339200225280/Cxatv7HG_normal.jpg",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/780246339200225280/Cxatv7HG_normal.jpg",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "follow_request_sent": false,
#         "protected": false,
#         "is_translation_enabled": false,
#         "has_extended_profile": true,
#         "screen_name": "CBMANTRI123456",
#         "entities": {
#           "description": {
#             "urls": []
#           }
#         },
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_background_tile": false,
#         "followers_count": 277,
#         "time_zone": null,
#         "contributors_enabled": false,
#         "location": "",
#         "following": false,
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "verified": false,
#         "lang": "en",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/2513278904/1474860196",
#         "utc_offset": null,
#         "created_at": "Wed May 21 18:11:48 +0000 2014",
#         "profile_text_color": "333333",
#         "url": null,
#         "favourites_count": 78196,
#         "profile_link_color": "0084B4",
#         "statuses_count": 124625,
#         "is_translator": false,
#         "listed_count": 126,
#         "geo_enabled": false,
#         "friends_count": 124,
#         "default_profile_image": false,
#         "profile_background_color": "C0DEED",
#         "translator_type": "none",
#         "default_profile": true,
#         "description": "",
#         "id_str": "2513278904",
#         "id": 2513278904,
#         "name": "CHANDRA BHANU MANTRI"
#       },
#       "text": "RT @Odishanews360: #Pakistan Trying To Rope In #China To Counter #India At #SAARC #IndiaPakistan\nhttps://t.co/7QeBTGkOM9 https://t.co/yBGka\u2026",
#       "geo": null,
#       "id": 786104397763928064,
#       "truncated": false
#     }
#   ]
# }

# %%
statuses = search_results['statuses']

# %% [markdown]
# #### <em>tutorial</em>
#
# So what is the meaning of \*args and \*\*kwargs,
#
#
# <em>\*args</em>
# We would use \*args when we are not sure how many arguments to be passed for example
# ```python
# >>> def print_everything(*args):
#         for count, thing in enumerate(args):
# ...         print '{0}. {1}'.format(count, thing)
# ...
# >>> print_everything('apple', 'banana', 'cabbage')
# 0. apple
# 1. banana
# 2. cabbage
# ```
#
# <em>\*kwargs</em>
# We would use \*\*kwargs when we are not sure how many "named" arguments to be passed for example
# ```python
# >>> def table_things(**kwargs):
# ...     for name, value in kwargs.items():
# ...         print '{0} = {1}'.format(name, value)
# ...
# >>> table_things(apple = 'fruit', cabbage = 'vegetable')
# cabbage = vegetable
# apple = fruit
# ```

# %%
for _ in range(5):
    print ("Length of status List",len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError:
        break
        
    kwargs = dict([kv.split('=') for kv in next_results[1:].split('&')])
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']
    
print (json.dumps(statuses[0],indent =2))
# Out:
# Length of status List 100
# Length of status List 170
# {
#   "favorited": false,
#   "favorite_count": 0,
#   "place": null,
#   "retweet_count": 2,
#   "is_quote_status": false,
#   "coordinates": null,
#   "lang": "en",
#   "entities": {
#     "hashtags": [
#       {
#         "indices": [
#           117,
#           131
#         ],
#         "text": "IndiaPakistan"
#       }
#     ],
#     "urls": [],
#     "symbols": [],
#     "user_mentions": [
#       {
#         "indices": [
#           3,
#           13
#         ],
#         "name": "Anu Tomar",
#         "id_str": "768396071097737216",
#         "id": 768396071097737216,
#         "screen_name": "iam_anu12"
#       }
#     ]
#   },
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_status_id": null,
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "created_at": "Tue Oct 18 08:45:52 +0000 2016",
#   "contributors": null,
#   "in_reply_to_screen_name": null,
#   "id_str": "788300050837278720",
#   "retweeted_status": {
#     "favorited": false,
#     "favorite_count": 2,
#     "place": null,
#     "retweet_count": 2,
#     "coordinates": null,
#     "lang": "en",
#     "entities": {
#       "hashtags": [
#         {
#           "indices": [
#             102,
#             116
#           ],
#           "text": "IndiaPakistan"
#         }
#       ],
#       "urls": [],
#       "symbols": [],
#       "user_mentions": []
#     },
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_status_id": null,
#     "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#     "created_at": "Tue Oct 18 08:37:07 +0000 2016",
#     "contributors": null,
#     "in_reply_to_screen_name": null,
#     "id_str": "788297848274026496",
#     "is_quote_status": false,
#     "metadata": {
#       "iso_language_code": "en",
#       "result_type": "recent"
#     },
#     "in_reply_to_status_id_str": null,
#     "retweeted": false,
#     "user": {
#       "notifications": false,
#       "profile_use_background_image": true,
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/781095000352227328/AsGPF9Pv_normal.jpg",
#       "profile_sidebar_border_color": "C0DEED",
#       "profile_image_url": "http://pbs.twimg.com/profile_images/781095000352227328/AsGPF9Pv_normal.jpg",
#       "profile_background_image_url_https": null,
#       "follow_request_sent": false,
#       "protected": false,
#       "is_translation_enabled": false,
#       "has_extended_profile": true,
#       "screen_name": "iam_anu12",
#       "entities": {
#         "description": {
#           "urls": []
#         },
#         "url": {
#           "urls": [
#             {
#               "indices": [
#                 0,
#                 23
#               ],
#               "display_url": "theconstantinconstant.blogspot.com",
#               "expanded_url": "http://theconstantinconstant.blogspot.com",
#               "url": "https://t.co/o8Qj5ZQ3Ma"
#             }
#           ]
#         }
#       },
#       "profile_sidebar_fill_color": "DDEEF6",
#       "profile_background_tile": false,
#       "followers_count": 77,
#       "time_zone": "Pacific Time (US & Canada)",
#       "contributors_enabled": false,
#       "location": "",
#       "following": false,
#       "profile_background_image_url": null,
#       "verified": false,
#       "lang": "en-gb",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/768396071097737216/1474976123",
#       "utc_offset": -25200,
#       "created_at": "Wed Aug 24 10:34:34 +0000 2016",
#       "profile_text_color": "333333",
#       "url": "https://t.co/o8Qj5ZQ3Ma",
#       "favourites_count": 243,
#       "profile_link_color": "2B7BB9",
#       "statuses_count": 402,
#       "is_translator": false,
#       "listed_count": 3,
#       "geo_enabled": false,
#       "friends_count": 99,
#       "default_profile_image": false,
#       "profile_background_color": "F5F8FA",
#       "translator_type": "none",
#       "default_profile": true,
#       "description": "A global citizen|Nationalist|Feminist but not Misandrist|Proud Indian|\u201cDemocracy and dialogue\u201d is only for those who swear loyalty to the Indian Constitution.",
#       "id_str": "768396071097737216",
#       "id": 768396071097737216,
#       "name": "Anu Tomar"
#     },
#     "text": "The 2 neighbors shared so much history &amp; culture but I think we've reached a saturation point now #IndiaPakistan",
#     "geo": null,
#     "id": 788297848274026496,
#     "truncated": false
#   },
#   "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#   },
#   "in_reply_to_status_id_str": null,
#   "retweeted": false,
#   "user": {
#     "notifications": false,
#     "profile_use_background_image": true,
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/784247211152412672/qyMN3Eo7_normal.jpg",
#     "profile_sidebar_border_color": "C0DEED",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/784247211152412672/qyMN3Eo7_normal.jpg",
#     "profile_background_image_url_https": null,
#     "follow_request_sent": false,
#     "protected": false,
#     "is_translation_enabled": false,
#     "has_extended_profile": true,
#     "screen_name": "HimalaySingh93",
#     "entities": {
#       "description": {
#         "urls": []
#       }
#     },
#     "profile_sidebar_fill_color": "DDEEF6",
#     "profile_background_tile": false,
#     "followers_count": 320,
#     "time_zone": null,
#     "contributors_enabled": false,
#     "location": "Meerut, India",
#     "following": false,
#     "profile_background_image_url": null,
#     "verified": false,
#     "lang": "en",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/755097296103170048/1470023315",
#     "utc_offset": null,
#     "created_at": "Mon Jul 18 17:49:59 +0000 2016",
#     "profile_text_color": "333333",
#     "url": null,
#     "favourites_count": 24517,
#     "profile_link_color": "2B7BB9",
#     "statuses_count": 22507,
#     "is_translator": false,
#     "listed_count": 32,
#     "geo_enabled": false,
#     "friends_count": 453,
#     "default_profile_image": false,
#     "profile_background_color": "F5F8FA",
#     "translator_type": "none",
#     "default_profile": true,
#     "description": "",
#     "id_str": "755097296103170048",
#     "id": 755097296103170048,
#     "name": "Himalay Singh"
#   },
#   "text": "RT @iam_anu12: The 2 neighbors shared so much history &amp; culture but I think we've reached a saturation point now #IndiaPakistan",
#   "geo": null,
#   "id": 788300050837278720,
#   "truncated": false
# }

# %% [markdown]
# #### Extracting tweet Entities

# %%
status_text = [status['text'] for status in statuses]

# %%
screen_names = [user_mention['screen_name'] for status in statuses for user_mention in status['entities']['user_mentions']]

# %%
hashtags = [hashtags['text'] for status in statuses for hashtags in status['entities']['hashtags']]

# %%
import pandas as pd
pd.set_option('max_colwidth', 10000)
pd.DataFrame({'Tweets':status_text[:5],'Screen_Names':screen_names[:5],'hashtags':hashtags[:5]})
# Out:
#     Screen_Names  \
# 0      iam_anu12
# 1      iam_anu12
# 2  SputnikNewsUS
# 3   amankiasha_1
# 4  SputnikNewsUS
#
#                                                                                                                                          Tweets  \
# 0           RT @iam_anu12: The 2 neighbors shared so much history &amp; culture but I think we've reached a saturation point now #IndiaPakistan
# 1           RT @iam_anu12: The 2 neighbors shared so much history &amp; culture but I think we've reached a saturation point now #IndiaPakistan
# 2  RT @SputnikNewsUS: Birds of war: #Pigeons are #spying for #security agencies on #IndiaPakistan border https://t.co/5uUoZvnE68 https://t.co/…
# 3                          The 2 neighbors shared so much history &amp; culture but I think we've reached a saturation point now #IndiaPakistan
# 4            Birds of war: #Pigeons are #spying for #security agencies on #IndiaPakistan border https://t.co/5uUoZvnE68 https://t.co/kJArO2Mx5E
#
#         hashtags
# 0  IndiaPakistan
# 1  IndiaPakistan
# 2        Pigeons
# 3         spying
# 4       security
#
# [5 rows x 3 columns]

# %% [markdown]
# #### frequency analysis of tweet and tweet entities

# %%
def count_words(text):
    words = ' '.join(i.lower() for i in text).split(' ')
    unique_words = set(words)
    count_words = [(word,words.count(word)) for word in unique_words]
    count_words = sorted(count_words,key = lambda x:x[1],reverse = True)
    return count_words
    pass

# %%
import numpy as np
count_status_words = np.array(count_words(status_text))
count_screen_name_words = np.array(count_words(screen_names))
count_hashtags = np.array(count_words(hashtags))

# %%
pd.DataFrame({'status_W':count_status_words[:10,0],'status_WF':count_status_words[:10,1],'screen_name':count_screen_name_words[:10,0],'screen_name_WF':count_screen_name_words[:10,1],'hashtags':count_hashtags[:10,0],'hashtags_WF':count_hashtags[:10,1]})
# Out:
#          hashtags hashtags_WF      screen_name screen_name_WF        status_W  \
# 0   indiapakistan         130        dawn_news              9  #indiapakistan
# 1        pakistan          23  ricardo_hausman              8              rt
# 2  surgicalstrike           8    amarujalanews              8              of
# 3           peace           8  mominamustehsan              8             the
# 4          spying           7    vinaynagaraju              8              to
# 5         kashmir           7          dailyo_              6              is
# 6         pigeons           7       perkovichg              4               a
# 7        security           7     tabindanaeem              4              کے
# 8         pakarmy           6         shehzilm              4       #pakistan
# 9        indiapak           6        sehrish__              4              it
#
#   status_WF
# 0        96
# 1        80
# 2        42
# 3        42
# 4        34
# 5        29
# 6        22
# 7        20
# 8        20
# 9        18
#
# [10 rows x 6 columns]

# %% [markdown]
# #### Analysing lexical diversity of the tweets
#
# By lexical diversity we analyse the count of different words used per tweet. It is significant as it may happen a user uses a single prase a lot of time like 'other stuff' this actually decreases the information gain per tweet. Thus a single use of word stuff may hold a mean in a tweet. So we are going to analyse that.

# %%
#lexical diversity of status_words
print (len(count_status_words[:,0])/sum(count_status_words[:,1].astype(int)))

#average words per tweet
print (1.0*sum(count_status_words[:,1].astype(int))/len(status_text))

#lexical diversity of screen_name
print (len(count_screen_name_words[:,0])/sum(count_screen_name_words[:,1].astype(int)))

#lexical diversity of hashtags
print(len(count_hashtags[:,0])/sum(count_hashtags[:,1].astype(int)))
# Out:
# 0.345801830481
# 14.7823529412
# 0.484848484848
# 0.255936675462

# %%
retweets = [(status['retweet_count'],status['retweeted_status']['user']['screen_name'],status['text']) for status in statuses if 'retweeted_status' in status]
retweets = sorted(retweets,key = lambda x:x[0],reverse = True)
pd.DataFrame(retweets)
# Out:
#       0                1  \
# 0   766  MominaMustehsan
# 1   766  MominaMustehsan
# 2   766  MominaMustehsan
# 3   766  MominaMustehsan
# 4   766  MominaMustehsan
# 5   766  MominaMustehsan
# 6   766  MominaMustehsan
# 7   238     timesofindia
# 8    97   KapilSibalteam
# 9    42    KailashOnline
# 10   15    TheFootieGirl
# 11   15    TheFootieGirl
# 12   14          DailyO_
# 13   11     tabindanaeem
# 14   11     tabindanaeem
# 15   11     tabindanaeem
# 16   11     tabindanaeem
# 17   10         shehzilm
# 18   10         shehzilm
# 19   10         shehzilm
# 20   10         shehzilm
# 21    9    VinayNagaraju
# 22    9    VinayNagaraju
# 23    9    VinayNagaraju
# 24    9    VinayNagaraju
# 25    9    VinayNagaraju
# 26    9    VinayNagaraju
# 27    9    VinayNagaraju
# 28    8        Dawn_News
# 29    8        Dawn_News
# 30    8        Dawn_News
# 31    8        Dawn_News
# 32    8        Dawn_News
# 33    8        Dawn_News
# 34    8        Dawn_News
# 35    8        Dawn_News
# 36    8          DailyO_
# 37    8          DailyO_
# 38    8          DailyO_
# 39    8          DailyO_
# 40    8          DailyO_
# 41    7        Dawn_News
# 42    7   hemantmorparia
# 43    7         latkhoor
# 44    7    AmarUjalaNews
# 45    7    AmarUjalaNews
# 46    7    AmarUjalaNews
# 47    7    AmarUjalaNews
# 48    7    AmarUjalaNews
# 49    4        sehrish__
# 50    4           MensXP
# 51    4        sehrish__
# 52    4        sehrish__
# 53    4        sehrish__
# 54    3    SputnikNewsUS
# 55    3    SputnikNewsUS
# 56    3       tkassenova
# 57    3       tkassenova
# 58    3       tkassenova
# 59    3          ShujaUH
#     ...              ...
#
#                                                                                                                                                  2
# 0    RT @MominaMustehsan: "Ask those about wars who have attended funerals of loved ones". \nWar is never the solution. We all want #peace. #Indi…
# 1    RT @MominaMustehsan: "Ask those about wars who have attended funerals of loved ones". \nWar is never the solution. We all want #peace. #Indi…
# 2    RT @MominaMustehsan: "Ask those about wars who have attended funerals of loved ones". \nWar is never the solution. We all want #peace. #Indi…
# 3    RT @MominaMustehsan: "Ask those about wars who have attended funerals of loved ones". \nWar is never the solution. We all want #peace. #Indi…
# 4    RT @MominaMustehsan: "Ask those about wars who have attended funerals of loved ones". \nWar is never the solution. We all want #peace. #Indi…
# 5    RT @MominaMustehsan: "Ask those about wars who have attended funerals of loved ones". \nWar is never the solution. We all want #peace. #Indi…
# 6    RT @MominaMustehsan: "Ask those about wars who have attended funerals of loved ones". \nWar is never the solution. We all want #peace. #Indi…
# 7           RT @timesofindia: Today's toon by Sandeep Adhwaryu \n\n#IndiaPakistan #IndianArmy #SurgicalStrikes #UriAttacks https://t.co/6fGgf48wp9
# 8    RT @KapilSibalteam: You have really come a long way bro since we parted, they have made u their army chief. #IndiaPakistan \n@KapilSibal htt…
# 9      RT @KailashOnline: 1965 के #IndiaPakistan युद्ध में अपने शौर्य व पराक्रम से दुश्मन सेना में खलबली मचा देने वाले #Virchakra से सम्मानित शूर…
# 10        RT @TheFootieGirl: @thenewshour Just so you know, @mshaanshahid is Pakistan's biggest movie star. #IndiaPakistan https://t.co/KS77lrD0Ox
# 11        RT @TheFootieGirl: @thenewshour Just so you know, @mshaanshahid is Pakistan's biggest movie star. #IndiaPakistan https://t.co/KS77lrD0Ox
# 12    RT @DailyO_: Is India prepared to wage a covert war on #Pakistan? | @virsanghvi | https://t.co/9qBvoMkXVs #IndiaPakistan https://t.co/ALDUJ…
# 13                                        RT @tabindanaeem: If it is only patriotic, then it is anything, but journalism. #IndiaPakistan #WarDrums
# 14                                        RT @tabindanaeem: If it is only patriotic, then it is anything, but journalism. #IndiaPakistan #WarDrums
# 15                                        RT @tabindanaeem: If it is only patriotic, then it is anything, but journalism. #IndiaPakistan #WarDrums
# 16                                        RT @tabindanaeem: If it is only patriotic, then it is anything, but journalism. #IndiaPakistan #WarDrums
# 17    RT @shehzilm: In Pakistan (after cricket) conspiracy theories happen to be our national pastime #IndiaPakistan #Pakistan https://t.co/z3bZE…
# 18    RT @shehzilm: In Pakistan (after cricket) conspiracy theories happen to be our national pastime #IndiaPakistan #Pakistan https://t.co/z3bZE…
# 19    RT @shehzilm: In Pakistan (after cricket) conspiracy theories happen to be our national pastime #IndiaPakistan #Pakistan https://t.co/z3bZE…
# 20    RT @shehzilm: In Pakistan (after cricket) conspiracy theories happen to be our national pastime #IndiaPakistan #Pakistan https://t.co/z3bZE…
# 21    RT @VinayNagaraju: India's trade with Pakistan desires more like peace... https://t.co/9GneuOQZ7d #IndiaPakistan @ricardo_hausman, @rodrikd…
# 22    RT @VinayNagaraju: India's trade with Pakistan desires more like peace... https://t.co/9GneuOQZ7d #IndiaPakistan @ricardo_hausman, @rodrikd…
# 23    RT @VinayNagaraju: India's trade with Pakistan desires more like peace... https://t.co/9GneuOQZ7d #IndiaPakistan @ricardo_hausman, @rodrikd…
# 24    RT @VinayNagaraju: India's trade with Pakistan desires more like peace... https://t.co/9GneuOQZ7d #IndiaPakistan @ricardo_hausman, @rodrikd…
# 25    RT @VinayNagaraju: India's trade with Pakistan desires more like peace... https://t.co/9GneuOQZ7d #IndiaPakistan @ricardo_hausman, @rodrikd…
# 26    RT @VinayNagaraju: India's trade with Pakistan desires more like peace... https://t.co/9GneuOQZ7d #IndiaPakistan @ricardo_hausman, @rodrikd…
# 27    RT @VinayNagaraju: India's trade with Pakistan desires more like peace... https://t.co/9GneuOQZ7d #IndiaPakistan @ricardo_hausman, @rodrikd…
# 28  RT @Dawn_News: بھارت کے ساتھ محض دکھاوے کے لیے مذاکرات نہیں کرنا چاہتے، پاکستانی ہائی کمشنر\nRead More:https://t.co/MBqI3tp1EU\n#IndiaPakista…
# 29  RT @Dawn_News: بھارت کے ساتھ محض دکھاوے کے لیے مذاکرات نہیں کرنا چاہتے، پاکستانی ہائی کمشنر\nRead More:https://t.co/MBqI3tp1EU\n#IndiaPakista…
# 30  RT @Dawn_News: بھارت کے ساتھ محض دکھاوے کے لیے مذاکرات نہیں کرنا چاہتے، پاکستانی ہائی کمشنر\nRead More:https://t.co/MBqI3tp1EU\n#IndiaPakista…
# 31  RT @Dawn_News: بھارت کے ساتھ محض دکھاوے کے لیے مذاکرات نہیں کرنا چاہتے، پاکستانی ہائی کمشنر\nRead More:https://t.co/MBqI3tp1EU\n#IndiaPakista…
# 32  RT @Dawn_News: بھارت کے ساتھ محض دکھاوے کے لیے مذاکرات نہیں کرنا چاہتے، پاکستانی ہائی کمشنر\nRead More:https://t.co/MBqI3tp1EU\n#IndiaPakista…
# 33  RT @Dawn_News: بھارت کے ساتھ محض دکھاوے کے لیے مذاکرات نہیں کرنا چاہتے، پاکستانی ہائی کمشنر\nRead More:https://t.co/MBqI3tp1EU\n#IndiaPakista…
# 34  RT @Dawn_News: بھارت کے ساتھ محض دکھاوے کے لیے مذاکرات نہیں کرنا چاہتے، پاکستانی ہائی کمشنر\nRead More:https://t.co/MBqI3tp1EU\n#IndiaPakista…
# 35  RT @Dawn_News: بھارت کے ساتھ محض دکھاوے کے لیے مذاکرات نہیں کرنا چاہتے، پاکستانی ہائی کمشنر\nRead More:https://t.co/MBqI3tp1EU\n#IndiaPakista…
# 36    RT @DailyO_: #IndiaPakistan situation is live and tense: Stop talking | Ajay Lele | https://t.co/I063PMROAF #SurgicalStrike https://t.co/zt…
# 37    RT @DailyO_: #IndiaPakistan situation is live and tense: Stop talking | Ajay Lele | https://t.co/I063PMROAF #SurgicalStrike https://t.co/zt…
# 38    RT @DailyO_: #IndiaPakistan situation is live and tense: Stop talking | Ajay Lele | https://t.co/I063PMROAF #SurgicalStrike https://t.co/zt…
# 39    RT @DailyO_: #IndiaPakistan situation is live and tense: Stop talking | Ajay Lele | https://t.co/I063PMROAF #SurgicalStrike https://t.co/zt…
# 40    RT @DailyO_: #IndiaPakistan situation is live and tense: Stop talking | Ajay Lele | https://t.co/I063PMROAF #SurgicalStrike https://t.co/zt…
# 41  RT @Dawn_News: بھارت ، پاکستان کو بھوٹان نہ سمجھے، ریٹائرڈ جنرل مشرف\nRead More:https://t.co/1Tk56RKPMC\n#IndiaPakistan https://t.co/darVl5Bc…
# 42    RT @hemantmorparia: now here's a tough choice for internet warriors: patriotism ? or consumerism? #IndiaPakistan  #Diwali https://t.co/ds22…
# 43  RT @latkhoor: #ceasefireviolations Akhnoor #SurgicalStrike #ModiPunishesPak #IndianArmy #Modi \n\nHow global powers reacted to #IndiaPakistan…
# 44   RT @AmarUjalaNews: भारत के दबाव का असर, पाक ने कहा- युद्ध नहीं है विकल्प-https://t.co/IuCymKb9rC\n#indiapakistan #IndiaPakRelations #indiapak
# 45   RT @AmarUjalaNews: भारत के दबाव का असर, पाक ने कहा- युद्ध नहीं है विकल्प-https://t.co/IuCymKb9rC\n#indiapakistan #IndiaPakRelations #indiapak
# 46   RT @AmarUjalaNews: भारत के दबाव का असर, पाक ने कहा- युद्ध नहीं है विकल्प-https://t.co/IuCymKb9rC\n#indiapakistan #IndiaPakRelations #indiapak
# 47   RT @AmarUjalaNews: भारत के दबाव का असर, पाक ने कहा- युद्ध नहीं है विकल्प-https://t.co/IuCymKb9rC\n#indiapakistan #IndiaPakRelations #indiapak
# 48   RT @AmarUjalaNews: भारत के दबाव का असर, पाक ने कहा- युद्ध नहीं है विकल्प-https://t.co/IuCymKb9rC\n#indiapakistan #IndiaPakRelations #indiapak
# 49   RT @sehrish__: Today's #TopStories With me \n#IndiaPakistan #CPEC #PakChinaFriendship #pakarmy #PMNawaz #COAS #Muharram #Ashura #KashmirUnre…
# 50                    RT @MensXP: For everyone who feels war is necessary. You need to watch this video.\n\n#indiapakistan https://t.co/XO0xz2cORz
# 51   RT @sehrish__: Today's #TopStories With me \n#IndiaPakistan #CPEC #PakChinaFriendship #pakarmy #PMNawaz #COAS #Muharram #Ashura #KashmirUnre…
# 52   RT @sehrish__: Today's #TopStories With me \n#IndiaPakistan #CPEC #PakChinaFriendship #pakarmy #PMNawaz #COAS #Muharram #Ashura #KashmirUnre…
# 53   RT @sehrish__: Today's #TopStories With me \n#IndiaPakistan #CPEC #PakChinaFriendship #pakarmy #PMNawaz #COAS #Muharram #Ashura #KashmirUnre…
# 54    RT @SputnikNewsUS: Birds of war: #Pigeons are #spying for #security agencies on #IndiaPakistan border https://t.co/5uUoZv63eA https://t.co/…
# 55    RT @SputnikNewsUS: Birds of war: #Pigeons are #spying for #security agencies on #IndiaPakistan border https://t.co/5uUoZv63eA https://t.co/…
# 56    RT @tkassenova: .@PerkovichG - even if solving Kashmir won't resolve all other problems, it will help 8 million souls (Kashmiris). #IndiaPa…
# 57    RT @tkassenova: .@PerkovichG - even if solving Kashmir won't resolve all other problems, it will help 8 million souls (Kashmiris). #IndiaPa…
# 58    RT @tkassenova: .@PerkovichG - even if solving Kashmir won't resolve all other problems, it will help 8 million souls (Kashmiris). #IndiaPa…
# 59                                                                           RT @ShujaUH: Ban films and win the wars? #HateIsstupid #IndiaPakistan
#                                                                                                                                                ...
#
# [80 rows x 3 columns]

# %% [markdown]
# #### Visualizing Frequency Data
